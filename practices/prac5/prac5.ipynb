# %% [markdown]
# <a href="https://colab.research.google.com/github/maxGrigorenko/RL/blob/prac5_Maksim_Grigorenko/practices/prac5/prac5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    import google.colab
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB = True
except:
    COLAB = False

# !pip install gymnasium==0.29.1 vizdoom==1.2.4 wandb==0.19.1
# Out:
# Collecting gymnasium==0.29.1
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Collecting vizdoom==1.2.4
#   Downloading vizdoom-1.2.4-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (11 kB)
# Collecting wandb==0.19.1
#   Downloading wandb-0.19.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.29.1) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.29.1) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.29.1) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.29.1) (0.0.4)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.12/dist-packages (from vizdoom==1.2.4) (2.6.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (8.3.0)
# Collecting docker-pycreds>=0.4.0 (from wandb==0.19.1)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (3.1.45)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (4.5.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (5.29.5)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (5.9.5)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (2.11.10)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (2.32.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (2.42.0)
# Collecting setproctitle (from wandb==0.19.1)
#   Downloading setproctitle-1.3.7-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.1) (75.2.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from docker-pycreds>=0.4.0->wandb==0.19.1) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb==0.19.1) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb==0.19.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb==0.19.1) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb==0.19.1) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.19.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.19.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.19.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.19.1) (2025.10.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb==0.19.1) (5.0.2)
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 10.0 MB/s eta 0:00:00
# Downloading vizdoom-1.2.4-cp312-cp312-manylinux_2_28_x86_64.whl (28.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.1/28.1 MB 4.2 MB/s eta 0:00:00
# Downloading wandb-0.19.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 85.7 MB/s eta 0:00:00
# Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Downloading setproctitle-1.3.7-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (32 kB)
# Installing collected packages: setproctitle, gymnasium, docker-pycreds, vizdoom, wandb
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.2.1
#     Uninstalling gymnasium-1.2.1:
#       Successfully uninstalled gymnasium-1.2.1
#   Attempting uninstall: wandb
#     Found existing installation: wandb 0.22.2
#     Uninstalling wandb-0.22.2:
#       Successfully uninstalled wandb-0.22.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.1 which is incompatible.
# Successfully installed docker-pycreds-0.4.0 gymnasium-0.29.1 setproctitle-1.3.7 vizdoom-1.2.4 wandb-0.19.1

# %%
import json
import math
import random
import sys
import os
import time
from collections import deque
from typing import Dict, Type, Any, Tuple, NamedTuple, Optional, Union, Generator, List

import gymnasium as gym
import gymnasium.spaces as spaces
from gymnasium.vector import AsyncVectorEnv, SyncVectorEnv
from gymnasium.wrappers import ResizeObservation, GrayScaleObservation, RecordEpisodeStatistics, TransformReward, \
    FrameStack
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn.functional as F
from torch import nn
from torch.distributions import Categorical
import vizdoom
from vizdoom import gymnasium_wrapper

try:
    import wandb
    WANDB_IS_AVAILABLE = True
except ImportError:
    WANDB_IS_AVAILABLE = False

os.environ["WANDB_API_KEY"] = "e97ffa4c776cbfb2c0fc0c8b5c97e875139c1d42"

# %% [markdown]
# # Градиент стратегии: REINFORCE
#
# Обозначения:
# - $s$ - состояние, $r$ - вознаграждение, $a$ - действие
# - Условное распределение действий $\pi(a | s)$ - стратегия агента
# - $\tau$ - траектория: $(s_0, r_0, a_0), \dots, (s_T, r_T, a_T)$
# - Отдача $G(\tau) = \sum_{t = 0} ^ T r_t \gamma ^ t$
# - $G_t = r_t + r_{t + 1} \gamma + \dots + r_{T} \gamma ^ {T - t}$
# - Функция полезности состояний: $V(s_{t}) = \mathbb{E}[G_t]$
# - Функция полезности действий: $Q(s_t, a_t) = \mathbb{E}[r_t + \gamma V(s_{t + 1}) | a_t]$
#
# В некоторых задачах для нахождения удовлетворительной стратегии необязательно в точности знать структуру всей среды. Например, в задаче поднятия кубика робототехнической рукой вместо точной аппроксимации полезности $Q(s,a)$ достаточно знать, что выгоднее: двигаться вправо, если кубик справа, и влево в ином случае. С этим же наблюдением связано и предположение, что задача поиска удовлетворительной стратегии проще, нежели задача точной оценки функции полезности.
#
# В данном семинаре познакомимся с простейшим методом прямой оптимизации стратегии REINFORCE, в котором параметры, задающие вероятностную стратегию, изменяются в соответствии с градиентом математического ожидания отдач:
#
# $$J(\theta)= \mathbb{E}[G(\tau)],$$
#
# $$\theta \leftarrow \theta +\alpha \nabla_{\theta} J(\theta),$$
#
# В первом выражении математическое ожидание берется по распределениям начальных состояний, вероятностным функциям переходов и вознаграждений среды, а также по вероятностной стратегии агента $\pi_\theta$. Благодаря теореме о существовании стационарного распределения марковской цепи, это выражение может быть переписано через стационарное распределение $d^\pi$ посещения состояний в среде:
#
# $$J(\theta)= \mathbb{E}_{s \sim d^\pi}[V^{\pi}(s)] = \mathbb{E}_{s \sim d^\pi, a \sim \pi(s)} [Q^{\pi}(s, a)] =: \mathbb{E}_\pi [Q^{\pi}(s, a)].$$
#
# Метод REINFORCE также использует теорему о градиенте стратегии, на основе которой построено целое семейство алгоритмов прямой оптимизации стратегии и актор-критиков. Теорема о градиенте стратегии связывает градиент целевой функции $J$ и градиент самой стратегии:
#
# $$\nabla_\theta J(\theta) = \mathbb{E}_\pi [Q^\pi(s, a) \nabla_\theta \ln \pi_\theta(a \vert s)]$$
#
# Для оценки полезности действий $Q^\pi(s, a)$ REINFORCE использует несмещенную Монте-Карло оценку на основе полученных в среде отдач $G_t$ (за некоторое фиксированное число эпизодов в среде). С учетом этого обновление весов осуществляется по правилу:
#
# $$\nabla_\theta J(\theta) = \mathbb{E}_\pi [G_t \nabla_\theta \ln \pi_\theta(a_t \vert s_t)]$$
#
# Более подробное (но все равно короткое) описание градиента стратегии, и в частности REINFORCE, можно посмотреть в [блоге Lilian Weng из OpenAI](https://lilianweng.github.io/posts/2018-04-08-policy-gradient/#policy-gradient), либо полноценно разобраться в соответствующей секции классического учебника Саттона и Барто.

# %% [markdown]
# ### Environment: Vizdoom
# Среда для экспериментов: **Vizdoom**. Задача: **VizdoomCorridor-v0**.
#
# Карта представляет собой коридор со стреляющими противниками по обеим сторонам. Зелёная броня размещена на противоположном конце коридора. Цель агента — добраться до предмета. Награда пропорциональна (отрицательна или положительна) изменению расстояния между игроком и жилетом.
# - Вознаграждение: +dX за приближение к броне, -dX за отдаление от брони, -100 за смерть.
# - Агенту доступны 7 действий: движение вперед/назад/влево/вправо, поворот влево/вправо, стрельба.
# - Ограничение по времени: 2100 шагов
#
# Для ускорения обучения агента рассматриваем самый простой уровень сложности `doom_skill = 1`.

# %%
def create_vizdoom_config(verbose=False):
    # Создаёт файл сценария VizdoomCorridor с уровнем сложности doom_skill = 1

    deadly_corridor_doom_skill_1 = """
    # Lines starting with # are treated as comments (or with whitespaces+#).
    # It doesn't matter if you use capital letters or not.
    # It doesn't matter if you use underscore or camel notation for keys, e.g. episode_timeout is the same as episodeTimeout.
    """
    deadly_corridor_doom_skill_1 += f"\ndoom_scenario_path = {os.path.relpath(os.path.dirname(vizdoom.__file__))}/scenarios/deadly_corridor.wad\n"
    deadly_corridor_doom_skill_1 += """
    # Skill 5 is recommended for the scenario to be a challenge.
    doom_skill = 1

    # Rewards
    death_penalty = 100
    #living_reward = 0

    # Rendering options
    screen_resolution = RES_320X240
    screen_format = CRCGCB
    render_hud = true
    render_crosshair = false
    render_weapon = true
    render_decals = false
    render_particles = false
    window_visible = true

    episode_timeout = 2100

    # Available buttons
    available_buttons =
      {
        MOVE_LEFT
        MOVE_RIGHT
        ATTACK
        MOVE_FORWARD
        MOVE_BACKWARD
        TURN_LEFT
        TURN_RIGHT
      }

    # Game variables that will be in the state
    available_game_variables = { HEALTH }

    mode = PLAYER
    """

    config_file_name = f'deadly_corridor_doom-skill-1.cfg'
    with open(config_file_name, 'w') as file_obj:
        print(deadly_corridor_doom_skill_1, file=file_obj)

    if verbose:
        print(deadly_corridor_doom_skill_1)

    return os.path.realpath(config_file_name)


def source_env_info():
    config_file_path = create_vizdoom_config()
    env = gym.make('VizdoomCorridor-v0', **{'scenario_file': config_file_path})
    obs, _ = env.reset()
    plt.imshow(obs['screen'])
    plt.show()
    print(env.env.env.spec.kwargs)

source_env_info()
# Out:
# /usr/local/lib/python3.12/dist-packages/vizdoom/gymnasium_wrapper/base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# {'scenario_file': '/content/deadly_corridor_doom-skill-1.cfg'}

# %% [markdown]
# ### Wrappers

# %%
class ImageExtractorWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
        self.observation_space = env.observation_space['screen']

    def observation(self, observation: Dict) -> np.ndarray:
        return observation['screen']


def make_env():
    config_file_path = create_vizdoom_config()
    env = gym.make('VizdoomCorridor-v0', **{'scenario_file': config_file_path})
    env = ImageExtractorWrapper(env)
    env = GrayScaleObservation(env)
    env = ResizeObservation(env, shape=84)
    env = FrameStack(env, num_stack=3)
    env = RecordEpisodeStatistics(env)
    env = TransformReward(env, f=lambda reward: reward / 100.)

    return env


def wrapped_env_info():
    config_file_path = create_vizdoom_config()
    env = make_env()
    env.reset()
    terminated = False
    while not terminated:
        obs, reward, terminated, truncated, info = env.step(env.action_space.sample())

    fig, axes = plt.subplots(1, 3, figsize=(12, 3))
    for ax, frame in zip(axes, obs):
        ax.imshow(frame, cmap='gray')

    print('Наблюдение - стек из 3х последовательных изображений 84х84 в оттенках серого, shape:', obs.shape)
    plt.show()
    print('info на последнем шаге содержит статистику эпизода: r - суммарное вознаграждение, l - длина эпизода, t - продолжительность эпизода в секундах\n', info)

DEMO_WRAPPED_ENV = True
if DEMO_WRAPPED_ENV:
    wrapped_env_info()
# Out:
# Наблюдение - стек из 3х последовательных изображений 84х84 в оттенках серого, shape: (3, 84, 84)
# info на последнем шаге содержит статистику эпизода: r - суммарное вознаграждение, l - длина эпизода, t - продолжительность эпизода в секундах
#  {'episode': {'r': array([104.40448], dtype=float32), 'l': array([2100], dtype=int32), 't': array([2.336853], dtype=float32)}}

# %% [markdown]
# ### Misc

# %%
def set_seed_everywhere(seed: int, using_cuda: bool = False) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    if using_cuda:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

# %% [markdown]
# # 1 REINFORCE

# %% [markdown]
# ### Policy
# Основные компоненты ReinforcePolicy:
# - `features_extractor` - свёрточный энкодер, кодирующий изображения в латентный вектор
# - `action_net` - полносвязный слой, который выдаёт логиты действий для предсказания вероятностей

# %% [markdown]
# ![policy](data:image/png;base64,...)

# %%
class Encoder(nn.Module):
    def __init__(
            self,
            observation_space: gym.Space,
            features_dim: int = 512,
    ) -> None:
        super().__init__()
        self.features_dim = features_dim
        n_input_channels = observation_space.shape[0]
        self.cnn = nn.Sequential(
            nn.Conv2d(n_input_channels, 32, kernel_size=8, stride=4, padding=0),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=0),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=0),
            nn.ReLU(),
            nn.Flatten(),
        )

        with torch.no_grad():
            n_flatten = self.cnn(torch.as_tensor(observation_space.sample()[None]).float()).shape[1]

        self.linear = nn.Sequential(nn.Linear(n_flatten, features_dim), nn.ReLU())

    def forward(self, observations: torch.Tensor) -> torch.Tensor:
        return self.linear(self.cnn(observations))


class ReinforcePolicy(nn.Module):
    def __init__(self, observation_space: gym.Space, action_space: gym.Space, lr: float,
                 optimizer_class: Type[torch.optim.Optimizer] = torch.optim.RMSprop,
                 optimizer_kwargs: Dict[str, Any] = {'eps': 1e-5},):
        super().__init__()
        self.observation_space = observation_space
        self.action_space = action_space
        self.lr = lr
        self.optimizer_class = optimizer_class
        self.optimizer_kwargs = dict(optimizer_kwargs)
        self.features_extractor = self.make_features_extractor()
        self.action_net = nn.Linear(self.features_extractor.features_dim, self.action_space.n)
        self.optimizer = self.optimizer_class(self.parameters(), lr=self.lr, **self.optimizer_kwargs)

    def make_features_extractor(self):
        return Encoder(self.observation_space)

    def extract_features(self, obs: torch.Tensor) -> torch.Tensor:
        obs = obs.float() / 255.
        features = self.features_extractor(obs)

        return features

    def forward(self, obs: torch.Tensor, deterministic: bool = False) -> Dict[str, torch.Tensor]:
        features = self.extract_features(obs)

        action_logits = self.action_net(features)
        distribution = Categorical(logits=action_logits)
        actions = distribution.mode() if deterministic else distribution.sample()
        actions = actions.reshape((-1, *self.action_space.shape))

        return {'features': features, 'action': actions}

    def evaluate_actions(self, obs: torch.Tensor, actions_taken: torch.Tensor) -> Dict[str, torch.Tensor]:
        features = self.extract_features(obs)
        action_logits = self.action_net(features)
        distribution = Categorical(logits=action_logits)
        log_prob = distribution.log_prob(actions_taken)
        entropy = distribution.entropy()

        return {'features': features, 'log_prob': log_prob, 'entropy': entropy}

    def set_training_mode(self, mode: bool) -> None:
        self.train(mode)

# %% [markdown]
# ### Buffer
# В буфере хранятся траектории, собранные агентом. Также в буфере производится вычисление частичных отдач по траекториям.

# %%
class BufferSamples(NamedTuple):
    observations: torch.Tensor
    actions: torch.Tensor
    returns: torch.Tensor


class Buffer:
    def __init__(
            self,
            gamma: float = 0.99,
            device: Union[torch.device, str] = "cpu",
    ):
        self.device = torch.device(device)
        self.gamma = gamma
        self.observations = None
        self.actions = None
        self.rewards = None
        self.returns = None

    def reset(self) -> None:
        self.observations = []
        self.actions = []
        self.rewards = []
        self.returns = None

    def size(self) -> int:
        return len(self.actions)

    def add(
            self,
            obs: np.ndarray,
            action: int,
            reward: float,
    ) -> None:
        self.observations.append(obs)
        self.actions.append(action)
        self.rewards.append(reward)

    def to_torch(self, array: np.ndarray) -> torch.Tensor:
        return torch.tensor(array, device=self.device)

    def _get_samples(
            self,
            batch_inds: np.ndarray,
    ) -> BufferSamples:
        observations = self.to_torch(self.observations[batch_inds])
        actions = self.to_torch(self.actions[batch_inds])
        returns = self.to_torch(self.returns[batch_inds])

        return BufferSamples(observations=observations, actions=actions, returns=returns)

    def get(self) -> BufferSamples:
        buffer_size = self.size()
        indices = np.random.permutation(buffer_size)
        self.observations = np.asarray(self.observations)
        self.actions = np.asarray(self.actions)
        self.returns = np.asarray(self.returns, dtype=np.float32)

        return self._get_samples(indices)

    def compute_returns(self) -> None:
        returns = [None] * len(self.rewards)
        reward_to_go = 0
        for step in reversed(range(len(self.rewards))):
            reward_to_go = self.rewards[step] + self.gamma * reward_to_go
            returns[step] = reward_to_go

        self.returns = returns

# %% [markdown]
# ### Обучение стратегии по методу REINFORCE
# - Метод `learn`: реализует основной цикл RL-обучения: чередование фазы сбора данных (траекторий) агентом в среде - `collect_rollouts` и фазы обучения агента - `train`.
# - Метод `collect_rollouts`: агент выполняет действия в среде согласно текущей стратегии, собирая триплеты **<observation, action, reward>** в буфер
# - Метод `train`: обучение на собранных данных. Функция потерь состоит из двух слагаемых: градиент стратегии и энтропийная регуляризация. Энтропийная регуляризация делает стратегию более стохастичной, т.е. более устойчивой к шуму, помогает исследовать среду, предотвращает сходимость к субоптимальному решению (особенно в средах с дискретными действиями)

# %% [markdown]
# ![learn](data:image/png;base64,...)

# %% [markdown]
# ![reinforce](data:image/png;base64,...)

# %%
class Reinforce:
    def __init__(
            self,
            env: gym.Env,
            learning_rate: float = 2.5e-4,
            gamma: float = 0.99,
            ent_coef: float = 0.001,
            max_grad_norm: float = 0.5,
            stats_window_size: int = 10,
            policy_class: Type[ReinforcePolicy] = ReinforcePolicy,
            policy_kwargs: Optional[Dict[str, Any]] = None,
            buffer_class: Type[Buffer] = Buffer,
            buffer_kwargs: Optional[Dict[str, Any]] = None,
            seed: Optional[int] = None,
            device: Union[torch.device, str] = "cuda",
    ):
        self.device = device if isinstance(device, torch.device) else torch.device(device)
        print(f"Using {self.device} device")

        self.policy_kwargs = {} if policy_kwargs is None else policy_kwargs

        self.num_timesteps = 0
        self._num_timesteps_at_start = 0
        self._episode_num = 0
        self.seed = seed
        self.start_time = 0.0
        self.learning_rate = learning_rate
        self._last_obs = None
        self._stats_window_size = stats_window_size
        self.ep_info_buffer = deque(maxlen=self._stats_window_size)
        self._n_updates = 0

        self.observation_space = env.observation_space
        self.action_space = env.action_space
        self.env = env

        self.n_steps = None
        self.gamma = gamma
        self.ent_coef = ent_coef
        self.max_grad_norm = max_grad_norm
        self.log_dict = {}

        self.set_random_seed(self.seed)
        self.buffer_class = buffer_class
        self.buffer_kwargs = {} if buffer_kwargs is None else buffer_kwargs
        self.buffer = self.buffer_class(
            device=self.device,
            gamma=self.gamma,
            **self.buffer_kwargs,
        )
        self.policy_class = policy_class
        self.policy = self.policy_class(
            self.observation_space, self.action_space, self.learning_rate, **self.policy_kwargs
        )
        self.policy = self.policy.to(self.device)

    def _update_info_buffer(self, info: Dict[str, Any]) -> None:
        # Collect statistics
        assert self.ep_info_buffer is not None

        ep_info = info.get("episode")
        if ep_info is not None:
            self.ep_info_buffer.append(ep_info)

    def set_random_seed(self, seed: Optional[int] = None) -> None:
        if seed is None:
            return
        set_seed_everywhere(seed, using_cuda=self.device.type == torch.device("cuda").type)
        self.action_space.seed(seed)
        self.observation_space.seed(seed)

    def collect_rollouts(
            self,
            env,
            buffer: Buffer,
    ):
        self.policy.set_training_mode(False)
        self._last_obs, _ = self.env.reset()
        self._last_obs = np.array(self._last_obs)
        assert self._last_obs is not None, "No previous observation was provided"

        buffer.reset()
        terminated = False
        while not terminated:
            with torch.no_grad():
                obs_tensor = torch.as_tensor(self._last_obs, device=self.device)
                action = self.policy(obs_tensor.unsqueeze(0))['action']
            action = action.item()
            new_obs, reward, terminated, truncated, info = env.step(action)
            assert not truncated, 'Episode truncation must be off as we want to use Monte Carlo estimation'

            self.num_timesteps += 1
            self._episode_num += int(terminated)
            buffer.add(
                self._last_obs,
                action,
                reward,
            )

            self._last_obs = np.array(new_obs)
            self._update_info_buffer(info)

        buffer.compute_returns()

    def train(self) -> None:
        self.policy.set_training_mode(True)

        rollout_data = self.buffer.get()
        actions = rollout_data.actions.long()
        policy_output = self.policy.evaluate_actions(rollout_data.observations, actions)
        log_prob = policy_output['log_prob']
        entropy = policy_output['entropy']
        returns = rollout_data.returns

        # Policy gradient loss
        policy_loss = -(returns * log_prob).mean()

        # Entropy loss
        entropy = torch.mean(entropy)
        entropy_loss = -self.ent_coef * entropy

        loss = policy_loss + entropy_loss

        # Optimization step
        self.policy.optimizer.zero_grad()
        loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
        self.policy.optimizer.step()

        self._n_updates += 1

        self.log_dict = dict([
            ("train/entropy_loss", entropy_loss.item()), ("train/entropy", entropy.item()),
            ("train/policy_gradient_loss", policy_loss.item()), ("train/loss", loss.item()),
            ("train/grad_norm", grad_norm.item()), ("train/n_updates", self._n_updates)
        ])

    def get_current_mean_return(self) -> float:
        if len(self.ep_info_buffer) == 0:
            return -math.inf

        return np.mean(np.concatenate([ep_info["r"] for ep_info in self.ep_info_buffer])).item()

    def _dump_logs(self, iteration: int) -> None:
        assert self.ep_info_buffer is not None

        time_elapsed = max((time.time_ns() - self.start_time) / 1e9, sys.float_info.epsilon)
        fps = int((self.num_timesteps - self._num_timesteps_at_start) / time_elapsed)
        self.log_dict["time/iterations"] = iteration
        if len(self.ep_info_buffer) > 0 and len(self.ep_info_buffer[0]) > 0:
            self.log_dict["rollout/ep_rew_mean"] = self.get_current_mean_return()
            self.log_dict["rollout/ep_len_mean"] = np.mean(
                np.concatenate([ep_info["l"] for ep_info in self.ep_info_buffer])).item()

        self.log_dict["time/fps"] = fps
        self.log_dict["time/time_elapsed"] = int(time_elapsed)
        self.log_dict["global_step"] = self.num_timesteps
        self.log_dict["num_episodes"] = self._episode_num
        print(json.dumps(self.log_dict, sort_keys=True, indent=4))

        if WANDB_IS_AVAILABLE and wandb.run is not None:
            wandb.log(self.log_dict)

    def learn(
            self,
            max_timesteps: int,
            expected_return: float,
            log_interval: int = 1000,
            save_checkpoint_path: str = None,
            save_checkpoint_interval: int = 5000,
    ) -> None:
        assert self.env is not None

        self.start_time = time.time_ns()
        self.num_timesteps = 0
        self._episode_num = 0
        self._num_timesteps_at_start = 0
        log_interval = log_interval or math.inf
        if save_checkpoint_path is None or save_checkpoint_interval is None or not COLAB:
            save_checkpoint_interval = math.inf

        next_log_step = self.num_timesteps + log_interval
        next_save_step = self.num_timesteps + save_checkpoint_interval

        if self._last_obs is None:
            self._last_obs, _ = self.env.reset(seed=self.seed)

        iteration = 0
        while True:
            if self.get_current_mean_return() >= expected_return:
                print('Решено!')
                break

            if self.num_timesteps >= max_timesteps:
                print(f'Задача не решена за {max_timesteps} шагов')
                break

            self.collect_rollouts(self.env, self.buffer, )
            iteration += 1

            if self.num_timesteps >= next_log_step:
                assert self.ep_info_buffer is not None
                self._dump_logs(iteration)
                next_log_step += log_interval

            if self.num_timesteps >= next_save_step:
                next_save_step += save_checkpoint_interval
                checkpoint = {'policy': self.policy.state_dict(), 'optimizer': self.policy.optimizer.state_dict(),
                              'num_timesteps': self.num_timesteps, 'episode_num': self._episode_num,
                              'ep_info_buffer': self.ep_info_buffer}
                os.makedirs(save_checkpoint_path, exist_ok=True)
                torch.save(checkpoint, os.path.join(save_checkpoint_path, 'checkpoint.pt'))

            self.train()

# %%
def run_algorithm(algorithm_class, algorithm_kwargs, use_wandb, wandb_kwargs, learn_kwargs):
    env = make_env()
    model = algorithm_class(env, **algorithm_kwargs)
    if use_wandb:
        config = {}
        config.update(algorithm_kwargs)
        config.update(learn_kwargs)
        config.update(wandb_kwargs.get('config', {}))
        wandb_kwargs['config'] = config
        if wandb.run is not None:
            wandb.finish()

        wandb.init(**wandb_kwargs)

    model.learn(**learn_kwargs)
    if use_wandb:
        wandb.finish()

# %%
run_algorithm(
    algorithm_class=Reinforce,
    algorithm_kwargs=dict(seed=0, ),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                      save_checkpoint_path='/content/drive/My Drive/seminar_actor-critic/reinforce',)
)
# Out:
# Using cuda device
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: ulaelfray. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/content/wandb/run-20251022_162458-6b8ndhx4</code>
# Syncing run <strong><a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/6b8ndhx4' target="_blank">reinforce</a></strong> to <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a>
#  View run at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/6b8ndhx4' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/6b8ndhx4</a>
# {
#     "global_step": 1006,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 335.3333333333333,
#     "rollout/ep_rew_mean": -76.22675323486328,
#     "time/fps": 272,
#     "time/iterations": 3,
#     "time/time_elapsed": 3,
#     "train/entropy": 2.0789310932159424,
#     "train/entropy_loss": -0.0020789310801774263,
#     "train/grad_norm": 0.012465535663068295,
#     "train/loss": -0.21674232184886932,
#     "train/n_updates": 2,
#     "train/policy_gradient_loss": -0.21466338634490967
# }
# {
#     "global_step": 2193,
#     "num_episodes": 6,
#     "rollout/ep_len_mean": 365.5,
#     "rollout/ep_rew_mean": -68.12448120117188,
#     "time/fps": 318,
#     "time/iterations": 6,
#     "time/time_elapsed": 6,
#     "train/entropy": 2.0788679122924805,
#     "train/entropy_loss": -0.002078867983072996,
#     "train/grad_norm": 0.025441385805606842,
#     "train/loss": -0.5018985271453857,
#     "train/n_updates": 5,
#     "train/policy_gradient_loss": -0.49981966614723206
# }
# {
#     "global_step": 4293,
#     "num_episodes": 7,
#     "rollout/ep_len_mean": 613.2857142857143,
#     "rollout/ep_rew_mean": -54.66374969482422,
#     "time/fps": 252,
#     "time/iterations": 7,
#     "time/time_elapsed": 17,
#     "train/entropy": 2.076836347579956,
#     "train/entropy_loss": -0.002076836535707116,
#     "train/grad_norm": 0.018119189888238907,
#     "train/loss": -0.3258703947067261,
#     "train/n_updates": 6,
#     "train/policy_gradient_loss": -0.32379356026649475
# }
# {
#     "global_step": 4699,
#     "num_episodes": 8,
#     "rollout/ep_len_mean": 587.375,
#     "rollout/ep_rew_mean": -55.357566833496094,
#     "time/fps": 242,
#     "time/iterations": 8,
#     "time/time_elapsed": 19,
#     "train/entropy": 2.074432134628296,
#     "train/entropy_loss": -0.0020744323264807463,
#     "train/grad_norm": 0.005937820766121149,
#     "train/loss": 0.02566981129348278,
#     "train/n_updates": 7,
#     "train/policy_gradient_loss": 0.027744242921471596
# }
# {
#     "global_step": 5211,
#     "num_episodes": 9,
#     "rollout/ep_len_mean": 579.0,
#     "rollout/ep_rew_mean": -59.53130340576172,
#     "time/fps": 213,
#     "time/iterations": 9,
#     "time/time_elapsed": 24,
#     "train/entropy": 2.0750622749328613,
#     "train/entropy_loss": -0.0020750623662024736,
#     "train/grad_norm": 0.03104863315820694,
#     "train/loss": -0.2880558669567108,
#     "train/n_updates": 8,
#     "train/policy_gradient_loss": -0.28598079085350037
# }
# {
#     "global_step": 6125,
#     "num_episodes": 12,
#     "rollout/ep_len_mean": 550.6,
#     "rollout/ep_rew_mean": -46.086456298828125,
#     "time/fps": 212,
#     "time/iterations": 12,
#     "time/time_elapsed": 28,
#     "train/entropy": 2.066114902496338,
#     "train/entropy_loss": -0.002066114917397499,
#     "train/grad_norm": 0.03470093011856079,
#     "train/loss": -0.4454176127910614,
#     "train/n_updates": 11,
#     "train/policy_gradient_loss": -0.44335150718688965
# }
# {
#     "global_step": 7001,
#     "num_episodes": 17,
#     "rollout/ep_len_mean": 270.8,
#     "rollout/ep_rew_mean": 726.15625,
#     "time/fps": 208,
#     "time/iterations": 17,
#     "time/time_elapsed": 33,
#     "train/entropy": 5.872422843822278e-05,
#     "train/entropy_loss": -5.872423258779236e-08,
#     "train/grad_norm": 0.002882734639570117,
#     "train/loss": 3.820510391960852e-05,
#     "train/n_updates": 16,
#     "train/policy_gradient_loss": 3.826382817351259e-05
# }
# {
#     "global_step": 8003,
#     "num_episodes": 23,
#     "rollout/ep_len_mean": 163.8,
#     "rollout/ep_rew_mean": 2101.619140625,
#     "time/fps": 220,
#     "time/iterations": 23,
#     "time/time_elapsed": 36,
#     "train/entropy": 3.0002549465280026e-05,
#     "train/entropy_loss": -3.000254977791883e-08,
#     "train/grad_norm": 0.00141418247949332,
#     "train/loss": 1.7505461073596962e-05,
#     "train/n_updates": 22,
#     "train/policy_gradient_loss": 1.7535463484819047e-05
# }
# Решено!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▂▄▅▅▆▇█</td></tr><tr><td>num_episodes</td><td>▁▂▂▃▃▄▆█</td></tr><tr><td>rollout/ep_len_mean</td><td>▄▄██▇▇▃▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▁▁▁▄█</td></tr><tr><td>time/fps</td><td>▅█▄▃▁▁▁▂</td></tr><tr><td>time/iterations</td><td>▁▂▂▃▃▄▆█</td></tr><tr><td>time/time_elapsed</td><td>▁▂▄▄▅▆▇█</td></tr><tr><td>train/entropy</td><td>██████▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▁▁██</td></tr><tr><td>train/grad_norm</td><td>▃▆▅▂▇█▁▁</td></tr><tr><td>train/loss</td><td>▅▁▃█▄▂██</td></tr><tr><td>train/n_updates</td><td>▁▂▂▃▃▄▆█</td></tr><tr><td>train/policy_gradient_loss</td><td>▅▁▃█▄▂██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>8003</td></tr><tr><td>num_episodes</td><td>23</td></tr><tr><td>rollout/ep_len_mean</td><td>163.8</td></tr><tr><td>rollout/ep_rew_mean</td><td>2101.61914</td></tr><tr><td>time/fps</td><td>220</td></tr><tr><td>time/iterations</td><td>23</td></tr><tr><td>time/time_elapsed</td><td>36</td></tr><tr><td>train/entropy</td><td>3e-05</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>0.00141</td></tr><tr><td>train/loss</td><td>2e-05</td></tr><tr><td>train/n_updates</td><td>22</td></tr><tr><td>train/policy_gradient_loss</td><td>2e-05</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">reinforce</strong> at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/6b8ndhx4' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/6b8ndhx4</a><br> View project at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251022_162458-6b8ndhx4/logs</code>

# %% [markdown]
# # 2 REINFORCE с базовым уровнем
# Градиент стратагии зависит от величины отдачи. Однако отдача может быть очень шумной оценкой $Q ^ {\pi} (s, a)$, особенно в средах с отложенными или редкими вознаграждениями. Этот шум приводит к высокой дисперсии в оценках градиента, что влечёт за собой сильные изменения стратегии. При этом обучение становится нестабильным, а сходимость медленной. Одним из способов снижения дисперсии является использование базового уровня $b(s)$. Базовый уровень $b(s)$ не зависит от действий, поэтому вычитание из оценки $Q ^ {\pi} (s, a)$ не приводит к смещению оценки градиента.
#
# $$\nabla_\theta J(\theta) = \mathbb{E}_\pi [(G_t - b(s)) \nabla_\theta \ln \pi_\theta(a_t \vert s_t)]$$
#
# ## 2.1 REINFORCE с необучаемым базовым уровнем (средняя отдача)
# В некоторых случаях в качестве базового уровня достаточно использовать среднюю отдачу за предыдущие эпизоды. Даже такая простая эвристика может помочь стабилизировать процесс обучения на ранних этапах.

# %% [markdown]
# (3 балла)

# %%
class AverageReturnBuffer(Buffer):
    def __init__(self, gamma: float = 0.99, device: Union[torch.device, str] = "cpu"):
        super().__init__(gamma, device)
        # Дополнительные переменные для вычисления средней отдачи
        self.total_returns = 0.0
        self.episode_count = 0
        self.avg_return = 0.

    def get_average_return(self):
        return self.avg_return

    def compute_returns(self) -> None:
        returns = [None] * len(self.rewards)
        reward_to_go = 0
        for i in reversed(range(len(self.rewards))):
            reward_to_go = self.rewards[i] + self.gamma * reward_to_go
            returns[i] = reward_to_go

        self.returns = returns
        if len(returns) != 0:
            self.total_returns += returns[0]
            self.episode_count += 1
            self.avg_return = self.total_returns / self.episode_count

# %% [markdown]
# (1 балл)

# %%
class AverageReturnBaselineReinforce(Reinforce):
    def __init__(self, env: gym.Env, learning_rate: float = 2.5e-4, gamma: float = 0.99, ent_coef: float = 0.001,
                 max_grad_norm: float = 0.5, stats_window_size: int = 10, policy_class: Type[ReinforcePolicy] = ReinforcePolicy,
                 policy_kwargs: Optional[Dict[str, Any]] = None, buffer_class: Type[AverageReturnBuffer] = AverageReturnBuffer,
                 buffer_kwargs: Optional[Dict[str, Any]] = None, seed: Optional[int] = None,
                 device: Union[torch.device, str] = "cuda"):
        super().__init__(env, learning_rate, gamma, ent_coef, max_grad_norm, stats_window_size, policy_class, policy_kwargs,
                         buffer_class, buffer_kwargs, seed, device)

    def train(self) -> None:
        self.policy.set_training_mode(True)

        rollout_data = self.buffer.get()
        actions = rollout_data.actions.long()
        policy_output = self.policy.evaluate_actions(rollout_data.observations, actions)
        log_prob = policy_output['log_prob']
        entropy = policy_output['entropy']

        # Получаем среднюю отдачу
        baseline = self.buffer.get_average_return()
        returns = rollout_data.returns - baseline

        # Policy gradient loss
        policy_loss = -(returns * log_prob).mean()

        # Entropy loss
        entropy = torch.mean(entropy)
        entropy_loss = -self.ent_coef * entropy

        loss = policy_loss + entropy_loss

        # Optimization step
        self.policy.optimizer.zero_grad()
        loss.backward()
        grad_norm = nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
        self.policy.optimizer.step()

        self._n_updates += 1

        self.log_dict = dict([
            ("train/entropy_loss", entropy_loss.item()), ("train/entropy", entropy.item()),
            ("train/policy_gradient_loss", policy_loss.item()), ("train/loss", loss.item()),
            ("train/grad_norm", grad_norm.item()), ("train/n_updates", self._n_updates),
            ("train/baseline", baseline)
        ])

# %%
run_algorithm(
    algorithm_class=AverageReturnBaselineReinforce,
    algorithm_kwargs=dict(seed=0, ),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_simple-baseline'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                    save_checkpoint_path='/content/drive/My Drive/seminar_actor-critic/reinforce_simple-baseline')
)
# Out:
# /usr/local/lib/python3.12/dist-packages/vizdoom/gymnasium_wrapper/base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# Using cuda device
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▂▂▃▃▄▅▅▅▆▆▇▇██</td></tr><tr><td>num_episodes</td><td>▁▁▂▂▃▃▄▅▅▅▆▆▇▇█</td></tr><tr><td>rollout/ep_len_mean</td><td>▁█▇▅▄▄▄▅▅▅▅▅▇▄▂</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▁▁▁▂▂▂▂▂▂▂▂█</td></tr><tr><td>time/fps</td><td>█▅▁▂▃▄▃▃▃▃▄▄▁▁▁</td></tr><tr><td>time/iterations</td><td>▁▁▂▂▃▃▄▅▅▅▆▆▇▇█</td></tr><tr><td>time/time_elapsed</td><td>▁▂▂▃▃▃▅▅▅▅▆▆███</td></tr><tr><td>train/baseline</td><td>▁▂▂▂▂▂▂▂▂▂▂▃▃▃█</td></tr><tr><td>train/entropy</td><td>█████████████▆▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▃█</td></tr><tr><td>train/grad_norm</td><td>▁▂▂▂▁▁▂▁▁▂▁▃▅█▂</td></tr><tr><td>train/loss</td><td>▆▁▇▆▄▁▂█▂▅▃▂█▆▅</td></tr><tr><td>train/n_updates</td><td>▁▁▂▂▃▃▄▅▅▅▆▆▇▇█</td></tr><tr><td>train/policy_gradient_loss</td><td>▆▁▇▆▄▁▂█▂▅▃▂█▆▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>15089</td></tr><tr><td>num_episodes</td><td>29</td></tr><tr><td>rollout/ep_len_mean</td><td>434.8</td></tr><tr><td>rollout/ep_rew_mean</td><td>737.0498</td></tr><tr><td>time/fps</td><td>397</td></tr><tr><td>time/iterations</td><td>29</td></tr><tr><td>time/time_elapsed</td><td>37</td></tr><tr><td>train/baseline</td><td>0.66711</td></tr><tr><td>train/entropy</td><td>0.00066</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>0.04023</td></tr><tr><td>train/loss</td><td>0.0005</td></tr><tr><td>train/n_updates</td><td>28</td></tr><tr><td>train/policy_gradient_loss</td><td>0.00051</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">reinforce_simple-baseline</strong> at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/yctiytaf' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/yctiytaf</a><br> View project at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251022_162539-yctiytaf/logs</code>
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/content/wandb/run-20251022_162653-0wt0ysxo</code>
# Syncing run <strong><a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/0wt0ysxo' target="_blank">reinforce_simple-baseline</a></strong> to <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a>
#  View run at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/0wt0ysxo' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/0wt0ysxo</a>
# {
#     "global_step": 1042,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 347.3333333333333,
#     "rollout/ep_rew_mean": -91.20339965820312,
#     "time/fps": 444,
#     "time/iterations": 3,
#     "time/time_elapsed": 2,
#     "train/baseline": -0.14535126808459922,
#     "train/entropy": 2.07906174659729,
#     "train/entropy_loss": -0.00207906193099916,
#     "train/grad_norm": 0.013570449315011501,
#     "train/loss": 0.03955921158194542,
#     "train/n_updates": 2,
#     "train/policy_gradient_loss": 0.04163827374577522
# }
# {
#     "global_step": 3142,
#     "num_episodes": 4,
#     "rollout/ep_len_mean": 785.5,
#     "rollout/ep_rew_mean": -50.58475875854492,
#     "time/fps": 397,
#     "time/iterations": 4,
#     "time/time_elapsed": 7,
#     "train/baseline": -0.08045289697277626,
#     "train/entropy": 2.0785484313964844,
#     "train/entropy_loss": -0.002078548539429903,
#     "train/grad_norm": 0.02816256880760193,
#     "train/loss": -0.4234488904476166,
#     "train/n_updates": 3,
#     "train/policy_gradient_loss": -0.42137032747268677
# }
# {
#     "global_step": 3479,
#     "num_episodes": 5,
#     "rollout/ep_len_mean": 695.8,
#     "rollout/ep_rew_mean": -48.51526641845703,
#     "time/fps": 385,
#     "time/iterations": 5,
#     "time/time_elapsed": 9,
#     "train/baseline": -0.05917670133631695,
#     "train/entropy": 2.0778822898864746,
#     "train/entropy_loss": -0.0020778824109584093,
#     "train/grad_norm": 0.01888107880949974,
#     "train/loss": 0.19081588089466095,
#     "train/n_updates": 4,
#     "train/policy_gradient_loss": 0.19289375841617584
# }
# {
#     "global_step": 4161,
#     "num_episodes": 7,
#     "rollout/ep_len_mean": 594.4285714285714,
#     "rollout/ep_rew_mean": -43.09572982788086,
#     "time/fps": 395,
#     "time/iterations": 7,
#     "time/time_elapsed": 10,
#     "train/baseline": -0.03249553125411949,
#     "train/entropy": 2.0774781703948975,
#     "train/entropy_loss": -0.002077478216961026,
#     "train/grad_norm": 0.020929699763655663,
#     "train/loss": 0.07459413260221481,
#     "train/n_updates": 6,
#     "train/policy_gradient_loss": 0.07667160779237747
# }
# {
#     "global_step": 5010,
#     "num_episodes": 9,
#     "rollout/ep_len_mean": 556.6666666666666,
#     "rollout/ep_rew_mean": -50.81547546386719,
#     "time/fps": 403,
#     "time/iterations": 9,
#     "time/time_elapsed": 12,
#     "train/baseline": -0.0401700103266207,
#     "train/entropy": 2.0776925086975098,
#     "train/entropy_loss": -0.0020776926539838314,
#     "train/grad_norm": 0.005736648570746183,
#     "train/loss": -0.17291955649852753,
#     "train/n_updates": 8,
#     "train/policy_gradient_loss": -0.17084185779094696
# }
# {
#     "global_step": 6066,
#     "num_episodes": 12,
#     "rollout/ep_len_mean": 544.7,
#     "rollout/ep_rew_mean": -52.6778450012207,
#     "time/fps": 410,
#     "time/iterations": 12,
#     "time/time_elapsed": 14,
#     "train/baseline": -0.015929930980567022,
#     "train/entropy": 2.0780258178710938,
#     "train/entropy_loss": -0.0020780258346349,
#     "train/grad_norm": 0.012891475111246109,
#     "train/loss": -0.46784526109695435,
#     "train/n_updates": 11,
#     "train/policy_gradient_loss": -0.4657672345638275
# }
# {
#     "global_step": 9043,
#     "num_episodes": 15,
#     "rollout/ep_len_mean": 556.4,
#     "rollout/ep_rew_mean": -22.2880916595459,
#     "time/fps": 403,
#     "time/iterations": 15,
#     "time/time_elapsed": 22,
#     "train/baseline": 0.014237431288399485,
#     "train/entropy": 2.0774238109588623,
#     "train/entropy_loss": -0.002077423967421055,
#     "train/grad_norm": 0.018013879656791687,
#     "train/loss": -0.3852110505104065,
#     "train/n_updates": 14,
#     "train/policy_gradient_loss": -0.3831336200237274
# }
# {
#     "global_step": 9622,
#     "num_episodes": 16,
#     "rollout/ep_len_mean": 578.8,
#     "rollout/ep_rew_mean": -31.99068260192871,
#     "time/fps": 405,
#     "time/iterations": 16,
#     "time/time_elapsed": 23,
#     "train/baseline": 0.023909376257671984,
#     "train/entropy": 2.077768087387085,
#     "train/entropy_loss": -0.0020777680911123753,
#     "train/grad_norm": 0.013041157275438309,
#     "train/loss": 0.2773374021053314,
#     "train/n_updates": 15,
#     "train/policy_gradient_loss": 0.27941516041755676
# }
# {
#     "global_step": 9914,
#     "num_episodes": 17,
#     "rollout/ep_len_mean": 575.3,
#     "rollout/ep_rew_mean": -25.2164249420166,
#     "time/fps": 405,
#     "time/iterations": 17,
#     "time/time_elapsed": 24,
#     "train/baseline": 0.02488623091373062,
#     "train/entropy": 2.0770277976989746,
#     "train/entropy_loss": -0.0020770279224961996,
#     "train/grad_norm": 0.017363203689455986,
#     "train/loss": -0.3757988512516022,
#     "train/n_updates": 16,
#     "train/policy_gradient_loss": -0.3737218379974365
# }
# {
#     "global_step": 10340,
#     "num_episodes": 18,
#     "rollout/ep_len_mean": 577.3,
#     "rollout/ep_rew_mean": -31.028350830078125,
#     "time/fps": 407,
#     "time/iterations": 18,
#     "time/time_elapsed": 25,
#     "train/baseline": 0.022605509645820452,
#     "train/entropy": 2.0744450092315674,
#     "train/entropy_loss": -0.0020744451321661472,
#     "train/grad_norm": 0.024469077587127686,
#     "train/loss": -0.05770194157958031,
#     "train/n_updates": 17,
#     "train/policy_gradient_loss": -0.0556274950504303
# }
# {
#     "global_step": 11151,
#     "num_episodes": 20,
#     "rollout/ep_len_mean": 585.7,
#     "rollout/ep_rew_mean": -24.191354751586914,
#     "time/fps": 410,
#     "time/iterations": 20,
#     "time/time_elapsed": 27,
#     "train/baseline": 0.024602221285447683,
#     "train/entropy": 2.074784517288208,
#     "train/entropy_loss": -0.0020747845992445946,
#     "train/grad_norm": 0.014240381307899952,
#     "train/loss": -0.24953006207942963,
#     "train/n_updates": 19,
#     "train/policy_gradient_loss": -0.24745528399944305
# }
# {
#     "global_step": 12318,
#     "num_episodes": 23,
#     "rollout/ep_len_mean": 595.8,
#     "rollout/ep_rew_mean": -8.926447868347168,
#     "time/fps": 413,
#     "time/iterations": 23,
#     "time/time_elapsed": 29,
#     "train/baseline": 0.028951883101886636,
#     "train/entropy": 2.063718557357788,
#     "train/entropy_loss": -0.0020637186244130135,
#     "train/grad_norm": 0.04950482025742531,
#     "train/loss": -0.3086313307285309,
#     "train/n_updates": 22,
#     "train/policy_gradient_loss": -0.30656760931015015
# }
# {
#     "global_step": 13968,
#     "num_episodes": 24,
#     "rollout/ep_len_mean": 702.5,
#     "rollout/ep_rew_mean": 22.838638305664062,
#     "time/fps": 412,
#     "time/iterations": 24,
#     "time/time_elapsed": 33,
#     "train/baseline": 0.046170780405592596,
#     "train/entropy": 1.9896305799484253,
#     "train/entropy_loss": -0.001989630749449134,
#     "train/grad_norm": 0.09598207473754883,
#     "train/loss": 0.2301935851573944,
#     "train/n_updates": 23,
#     "train/policy_gradient_loss": 0.23218321800231934
# }
# {
#     "global_step": 14188,
#     "num_episodes": 25,
#     "rollout/ep_len_mean": 514.5,
#     "rollout/ep_rew_mean": 23.142454147338867,
#     "time/fps": 410,
#     "time/iterations": 25,
#     "time/time_elapsed": 34,
#     "train/baseline": 0.0765071794561018,
#     "train/entropy": 1.623949646949768,
#     "train/entropy_loss": -0.00162394973449409,
#     "train/grad_norm": 0.17072506248950958,
#     "train/loss": 0.017210999503731728,
#     "train/n_updates": 24,
#     "train/policy_gradient_loss": 0.018834948539733887
# }
# {
#     "global_step": 15089,
#     "num_episodes": 29,
#     "rollout/ep_len_mean": 434.8,
#     "rollout/ep_rew_mean": 737.0498046875,
#     "time/fps": 412,
#     "time/iterations": 29,
#     "time/time_elapsed": 36,
#     "train/baseline": 0.6671119469953977,
#     "train/entropy": 0.0006571859121322632,
#     "train/entropy_loss": -6.571859216819576e-07,
#     "train/grad_norm": 0.040226906538009644,
#     "train/loss": 0.000504651281516999,
#     "train/n_updates": 28,
#     "train/policy_gradient_loss": 0.000505308446008712
# }
# {
#     "global_step": 16063,
#     "num_episodes": 35,
#     "rollout/ep_len_mean": 187.5,
#     "rollout/ep_rew_mean": 1796.6685791015625,
#     "time/fps": 414,
#     "time/iterations": 35,
#     "time/time_elapsed": 38,
#     "train/baseline": 1.7279866592718458,
#     "train/entropy": 9.214367310050875e-05,
#     "train/entropy_loss": -9.214367935328482e-08,
#     "train/grad_norm": 0.004510404076427221,
#     "train/loss": 5.041411714046262e-05,
#     "train/n_updates": 34,
#     "train/policy_gradient_loss": 5.050625986768864e-05
# }
# Решено!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▂▂▂▃▃▅▅▅▅▆▆▇▇██</td></tr><tr><td>num_episodes</td><td>▁▁▁▂▂▃▄▄▄▄▅▅▆▆▇█</td></tr><tr><td>rollout/ep_len_mean</td><td>▃█▇▆▅▅▅▆▆▆▆▆▇▅▄▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▄█</td></tr><tr><td>time/fps</td><td>█▂▁▂▃▄▃▃▃▄▄▄▄▄▄▄</td></tr><tr><td>time/iterations</td><td>▁▁▁▂▂▃▄▄▄▄▅▅▆▆▇█</td></tr><tr><td>time/time_elapsed</td><td>▁▂▂▃▃▃▅▅▅▅▆▆▇▇██</td></tr><tr><td>train/baseline</td><td>▁▁▁▁▁▁▂▂▂▂▂▂▂▂▄█</td></tr><tr><td>train/entropy</td><td>█████████████▆▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▃██</td></tr><tr><td>train/grad_norm</td><td>▁▂▂▂▁▁▂▁▂▂▁▃▅█▃▁</td></tr><tr><td>train/loss</td><td>▆▁▇▆▄▁▂█▂▅▃▂█▆▅▅</td></tr><tr><td>train/n_updates</td><td>▁▁▁▂▂▃▄▄▄▄▅▅▆▆▇█</td></tr><tr><td>train/policy_gradient_loss</td><td>▆▁▇▆▄▁▂█▂▅▃▂█▆▅▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>16063</td></tr><tr><td>num_episodes</td><td>35</td></tr><tr><td>rollout/ep_len_mean</td><td>187.5</td></tr><tr><td>rollout/ep_rew_mean</td><td>1796.66858</td></tr><tr><td>time/fps</td><td>414</td></tr><tr><td>time/iterations</td><td>35</td></tr><tr><td>time/time_elapsed</td><td>38</td></tr><tr><td>train/baseline</td><td>1.72799</td></tr><tr><td>train/entropy</td><td>9e-05</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>0.00451</td></tr><tr><td>train/loss</td><td>5e-05</td></tr><tr><td>train/n_updates</td><td>34</td></tr><tr><td>train/policy_gradient_loss</td><td>5e-05</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">reinforce_simple-baseline</strong> at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/0wt0ysxo' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/0wt0ysxo</a><br> View project at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251022_162653-0wt0ysxo/logs</code>

# %% [markdown]
# ## 2.2 REINFORCE с обучаемым базовым уровнем
# Чаще всего в качестве базового уровня применяется оценка функции полезности состояний $b(s) = v(s) = \mathbb{E}[G_t| s_t = s]$, получаемая с помощью нейросетевой аппроксимации. При этом величину $G_t - b(s_t)$ можно рассматривать как оценку функции преимущества (advantage) действия $a_t$ в состоянии $s_t$: $A(s_t, a_t) = Q(s_t, a_t) - V(s_t)$.
#
# #### Shared-encoder
# Модели стратегии и функции полезности могут обучаться в разных режимах — стратегия только on-policy (шаг обучения на текущей собранной подтраектории), а полезность on-policy или off-policy (шаг обучения на текущей подтраектории или на батче из replay buffer). Это с одной стороны привносит гибкость в обучение, с другой — усложняет его.
#
# Если обе модели обучаются on-policy, то имеет смысл объединить их сетки в одну и делать общий шаг обратного распространения ошибки. Однако, если они обучаются в разных режимах (и с разной частотой обновления), то велика вероятность, что их шаги обучения могут начать конфликтовать в случае общего тела — для такого варианта намного предпочтительнее разделить их на разные подсети (либо аккуратно настраивать гиперпарметры, чтобы стабилизировать обучение). В целом, рекомендуется использовать общий энкодер наблюдений, а далее как можно скорее разделять головы.

# %% [markdown]
# (2 балла)

# %%
import torch.distributions as dist

class ValuePolicy(ReinforcePolicy):
    def __init__(self, observation_space: gym.Space, action_space: gym.Space, lr: float,
                 optimizer_class: Type[torch.optim.Optimizer] = torch.optim.RMSprop,
                 optimizer_kwargs: Dict[str, Any] = {'eps': 1e-5}):
        super().__init__(observation_space, action_space, lr, optimizer_class, optimizer_kwargs)
        with torch.no_grad():
            dummy_obs = torch.as_tensor(observation_space.sample()[None], device="cpu")
            features = self.extract_features(dummy_obs)
            self.features_dim = features.shape[1]
        self.value_net = nn.Linear(self.features_dim, 1)
        self.optimizer = self.optimizer_class(self.parameters(), lr=lr, **optimizer_kwargs)

    def get_action_distribution(self, action_logits: torch.Tensor) -> dist.Distribution:
        return dist.Categorical(logits=action_logits)

    def evaluate_actions(self, obs: torch.Tensor, actions_taken: torch.Tensor) -> Dict[str, torch.Tensor]:
        features = self.extract_features(obs)
        action_logits = self.action_net(features)
        action_dist = self.get_action_distribution(action_logits)
        log_prob = action_dist.log_prob(actions_taken)
        entropy = action_dist.entropy()
        values = self.value_net(features).squeeze(-1)
        return {
            'features': features,
            'log_prob': log_prob,
            'entropy': entropy,
            'values': values
        }

# %% [markdown]
# (1 балл)

# %%
class ValueBaselineReinforce(Reinforce):
    def __init__(self, env: gym.Env, learning_rate: float = 2.5e-4, gamma: float = 0.99, ent_coef: float = 0.001,
                 max_grad_norm: float = 0.5, stats_window_size: int = 10, policy_class: Type[ValuePolicy] = ValuePolicy,
                 policy_kwargs: Optional[Dict[str, Any]] = None, buffer_class: Type[Buffer] = Buffer,
                 buffer_kwargs: Optional[Dict[str, Any]] = None, seed: Optional[int] = None,
                 device: Union[torch.device, str] = "cuda", vf_coef: float = 0.5,):
        super().__init__(env, learning_rate, gamma, ent_coef, max_grad_norm, stats_window_size, policy_class,
                         policy_kwargs, buffer_class, buffer_kwargs, seed, device)
        self.vf_coef = vf_coef

    def train(self) -> None:
        self.policy.set_training_mode(True)

        rollout_data = self.buffer.get()
        actions = rollout_data.actions.long()
        policy_output = self.policy.evaluate_actions(rollout_data.observations, actions)
        log_prob = policy_output['log_prob']
        entropy = policy_output['entropy']
        values = policy_output['values']
        advantages = rollout_data.returns - values.detach()
        baseline = values.mean().item()

        # Policy gradient loss
        policy_loss = -(advantages * log_prob).mean()

        # Entropy loss
        entropy = torch.mean(entropy)
        entropy_loss = -self.ent_coef * entropy

        # Value loss с коэффициентов self.vf_coef
        value_loss = self.vf_coef * F.mse_loss(values, rollout_data.returns)

        loss = policy_loss + entropy_loss + value_loss

        # Optimization step
        self.policy.optimizer.zero_grad()
        loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
        self.policy.optimizer.step()

        self._n_updates += 1

        self.log_dict = dict([
            ("train/entropy_loss", entropy_loss.item()), ("train/entropy", entropy.item()),
            ("train/policy_gradient_loss", policy_loss.item()), ("train/loss", loss.item()),
            ("train/grad_norm", grad_norm.item()), ("train/n_updates", self._n_updates),
            ("train/baseline", baseline), ("train/value_loss", value_loss.item())
        ])

# %%
run_algorithm(
    algorithm_class=ValueBaselineReinforce,
    algorithm_kwargs=dict(seed=0, ),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_value-baseline'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                    save_checkpoint_path='/content/drive/My Drive/seminar_actor-critic/reinforce_value-baseline')
)
# Out:
# Using cuda device
#  View run <strong style="color:#cdcd00">reinforce_value-baseline</strong> at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/ol0en6al' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/ol0en6al</a><br> View project at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251022_164729-ol0en6al/logs</code>
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/content/wandb/run-20251022_164758-4zi9m9d1</code>
# Syncing run <strong><a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/4zi9m9d1' target="_blank">reinforce_value-baseline</a></strong> to <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a>
#  View run at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/4zi9m9d1' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/4zi9m9d1</a>
# {
#     "global_step": 1333,
#     "num_episodes": 4,
#     "rollout/ep_len_mean": 333.25,
#     "rollout/ep_rew_mean": -64.95689392089844,
#     "time/fps": 431,
#     "time/iterations": 4,
#     "time/time_elapsed": 3,
#     "train/baseline": -0.07343289256095886,
#     "train/entropy": 2.078946113586426,
#     "train/entropy_loss": -0.002078946214169264,
#     "train/grad_norm": 0.27602052688598633,
#     "train/loss": -0.3122941255569458,
#     "train/n_updates": 3,
#     "train/policy_gradient_loss": -0.3885398507118225,
#     "train/value_loss": 0.07832467555999756
# }
# {
#     "global_step": 2004,
#     "num_episodes": 6,
#     "rollout/ep_len_mean": 334.0,
#     "rollout/ep_rew_mean": -76.94759368896484,
#     "time/fps": 435,
#     "time/iterations": 6,
#     "time/time_elapsed": 4,
#     "train/baseline": -0.06116688996553421,
#     "train/entropy": 2.0790462493896484,
#     "train/entropy_loss": -0.002079046331346035,
#     "train/grad_norm": 0.3127952218055725,
#     "train/loss": -0.4623798727989197,
#     "train/n_updates": 5,
#     "train/policy_gradient_loss": -0.526069164276123,
#     "train/value_loss": 0.06576837599277496
# }
# {
#     "global_step": 3069,
#     "num_episodes": 7,
#     "rollout/ep_len_mean": 438.42857142857144,
#     "rollout/ep_rew_mean": -82.09088897705078,
#     "time/fps": 397,
#     "time/iterations": 7,
#     "time/time_elapsed": 7,
#     "train/baseline": -0.12637336552143097,
#     "train/entropy": 2.0787744522094727,
#     "train/entropy_loss": -0.002078774617984891,
#     "train/grad_norm": 0.249507337808609,
#     "train/loss": -0.2901237905025482,
#     "train/n_updates": 6,
#     "train/policy_gradient_loss": -0.3356863856315613,
#     "train/value_loss": 0.04764137789607048
# }
# {
#     "global_step": 4276,
#     "num_episodes": 11,
#     "rollout/ep_len_mean": 403.5,
#     "rollout/ep_rew_mean": -75.08033752441406,
#     "time/fps": 409,
#     "time/iterations": 11,
#     "time/time_elapsed": 10,
#     "train/baseline": -0.37990498542785645,
#     "train/entropy": 2.0745646953582764,
#     "train/entropy_loss": -0.0020745648071169853,
#     "train/grad_norm": 0.6421160697937012,
#     "train/loss": 0.5066341757774353,
#     "train/n_updates": 10,
#     "train/policy_gradient_loss": 0.44705930352211,
#     "train/value_loss": 0.061649441719055176
# }
# {
#     "global_step": 5510,
#     "num_episodes": 13,
#     "rollout/ep_len_mean": 464.8,
#     "rollout/ep_rew_mean": -76.38328552246094,
#     "time/fps": 417,
#     "time/iterations": 13,
#     "time/time_elapsed": 13,
#     "train/baseline": -0.1747414469718933,
#     "train/entropy": 2.077655553817749,
#     "train/entropy_loss": -0.0020776556339114904,
#     "train/grad_norm": 0.03648706525564194,
#     "train/loss": 0.009147640317678452,
#     "train/n_updates": 12,
#     "train/policy_gradient_loss": -0.03536985069513321,
#     "train/value_loss": 0.046595145016908646
# }
# {
#     "global_step": 6244,
#     "num_episodes": 14,
#     "rollout/ep_len_mean": 491.1,
#     "rollout/ep_rew_mean": -76.1899185180664,
#     "time/fps": 421,
#     "time/iterations": 14,
#     "time/time_elapsed": 14,
#     "train/baseline": -0.18191519379615784,
#     "train/entropy": 2.077324151992798,
#     "train/entropy_loss": -0.002077324315905571,
#     "train/grad_norm": 0.16731683909893036,
#     "train/loss": 0.22414825856685638,
#     "train/n_updates": 13,
#     "train/policy_gradient_loss": 0.1963045299053192,
#     "train/value_loss": 0.029921051114797592
# }
# {
#     "global_step": 7077,
#     "num_episodes": 16,
#     "rollout/ep_len_mean": 507.3,
#     "rollout/ep_rew_mean": -72.10441589355469,
#     "time/fps": 423,
#     "time/iterations": 16,
#     "time/time_elapsed": 16,
#     "train/baseline": -0.11153870820999146,
#     "train/entropy": 2.0779874324798584,
#     "train/entropy_loss": -0.002077987417578697,
#     "train/grad_norm": 0.3955082595348358,
#     "train/loss": -0.4728027284145355,
#     "train/n_updates": 15,
#     "train/policy_gradient_loss": -0.5786095857620239,
#     "train/value_loss": 0.10788486152887344
# }
# {
#     "global_step": 8232,
#     "num_episodes": 19,
#     "rollout/ep_len_mean": 466.8,
#     "rollout/ep_rew_mean": -59.63811111450195,
#     "time/fps": 410,
#     "time/iterations": 19,
#     "time/time_elapsed": 20,
#     "train/baseline": -0.17366373538970947,
#     "train/entropy": 2.077362537384033,
#     "train/entropy_loss": -0.002077362732961774,
#     "train/grad_norm": 0.20848222076892853,
#     "train/loss": 0.3703927993774414,
#     "train/n_updates": 18,
#     "train/policy_gradient_loss": 0.2506125271320343,
#     "train/value_loss": 0.12185762077569962
# }
# {
#     "global_step": 9247,
#     "num_episodes": 22,
#     "rollout/ep_len_mean": 439.7,
#     "rollout/ep_rew_mean": -66.52615356445312,
#     "time/fps": 413,
#     "time/iterations": 22,
#     "time/time_elapsed": 22,
#     "train/baseline": -0.18114763498306274,
#     "train/entropy": 2.0767362117767334,
#     "train/entropy_loss": -0.002076736418530345,
#     "train/grad_norm": 0.27762478590011597,
#     "train/loss": -0.2277398705482483,
#     "train/n_updates": 21,
#     "train/policy_gradient_loss": -0.3063523471355438,
#     "train/value_loss": 0.0806892141699791
# }
# {
#     "global_step": 10203,
#     "num_episodes": 24,
#     "rollout/ep_len_mean": 395.9,
#     "rollout/ep_rew_mean": -74.59456634521484,
#     "time/fps": 417,
#     "time/iterations": 24,
#     "time/time_elapsed": 24,
#     "train/baseline": -0.21315208077430725,
#     "train/entropy": 2.0760130882263184,
#     "train/entropy_loss": -0.002076013246551156,
#     "train/grad_norm": 0.08987881988286972,
#     "train/loss": 0.11004720628261566,
#     "train/n_updates": 23,
#     "train/policy_gradient_loss": 0.09136412292718887,
#     "train/value_loss": 0.0207590963691473
# }
# {
#     "global_step": 12303,
#     "num_episodes": 25,
#     "rollout/ep_len_mean": 575.3,
#     "rollout/ep_rew_mean": -43.99215316772461,
#     "time/fps": 424,
#     "time/iterations": 25,
#     "time/time_elapsed": 28,
#     "train/baseline": -0.19737286865711212,
#     "train/entropy": 2.076380729675293,
#     "train/entropy_loss": -0.0020763808861374855,
#     "train/grad_norm": 0.0939793735742569,
#     "train/loss": 0.20254886150360107,
#     "train/n_updates": 24,
#     "train/policy_gradient_loss": 0.11051029711961746,
#     "train/value_loss": 0.09411494433879852
# }
# {
#     "global_step": 12707,
#     "num_episodes": 26,
#     "rollout/ep_len_mean": 563.0,
#     "rollout/ep_rew_mean": -42.22178649902344,
#     "time/fps": 423,
#     "time/iterations": 26,
#     "time/time_elapsed": 30,
#     "train/baseline": -0.183307945728302,
#     "train/entropy": 2.0762698650360107,
#     "train/entropy_loss": -0.0020762700587511063,
#     "train/grad_norm": 0.501456081867218,
#     "train/loss": 0.6254332065582275,
#     "train/n_updates": 25,
#     "train/policy_gradient_loss": 0.5710477232933044,
#     "train/value_loss": 0.05646174028515816
# }
# {
#     "global_step": 13222,
#     "num_episodes": 28,
#     "rollout/ep_len_mean": 549.3,
#     "rollout/ep_rew_mean": -38.14500045776367,
#     "time/fps": 418,
#     "time/iterations": 28,
#     "time/time_elapsed": 31,
#     "train/baseline": -0.11201216280460358,
#     "train/entropy": 2.0775673389434814,
#     "train/entropy_loss": -0.0020775673910975456,
#     "train/grad_norm": 0.06431827694177628,
#     "train/loss": -0.016978144645690918,
#     "train/n_updates": 27,
#     "train/policy_gradient_loss": -0.08434126526117325,
#     "train/value_loss": 0.06944068521261215
# }
# {
#     "global_step": 14306,
#     "num_episodes": 31,
#     "rollout/ep_len_mean": 538.7,
#     "rollout/ep_rew_mean": -30.928333282470703,
#     "time/fps": 415,
#     "time/iterations": 31,
#     "time/time_elapsed": 34,
#     "train/baseline": -0.16024045646190643,
#     "train/entropy": 2.0764245986938477,
#     "train/entropy_loss": -0.0020764246582984924,
#     "train/grad_norm": 0.07746818661689758,
#     "train/loss": -0.06216498836874962,
#     "train/n_updates": 30,
#     "train/policy_gradient_loss": -0.09409822523593903,
#     "train/value_loss": 0.0340096615254879
# }
# {
#     "global_step": 15022,
#     "num_episodes": 33,
#     "rollout/ep_len_mean": 536.0,
#     "rollout/ep_rew_mean": -28.090900421142578,
#     "time/fps": 416,
#     "time/iterations": 33,
#     "time/time_elapsed": 36,
#     "train/baseline": -0.1764722764492035,
#     "train/entropy": 2.075972318649292,
#     "train/entropy_loss": -0.0020759725011885166,
#     "train/grad_norm": 0.1085691899061203,
#     "train/loss": -0.07611323148012161,
#     "train/n_updates": 32,
#     "train/policy_gradient_loss": -0.12382379919290543,
#     "train/value_loss": 0.04978654533624649
# }
# {
#     "global_step": 16828,
#     "num_episodes": 35,
#     "rollout/ep_len_mean": 452.5,
#     "rollout/ep_rew_mean": -26.292261123657227,
#     "time/fps": 420,
#     "time/iterations": 35,
#     "time/time_elapsed": 39,
#     "train/baseline": -0.14808236062526703,
#     "train/entropy": 2.07656192779541,
#     "train/entropy_loss": -0.002076562028378248,
#     "train/grad_norm": 0.29536503553390503,
#     "train/loss": 0.43475857377052307,
#     "train/n_updates": 34,
#     "train/policy_gradient_loss": 0.382823646068573,
#     "train/value_loss": 0.05401148274540901
# }
# {
#     "global_step": 17169,
#     "num_episodes": 36,
#     "rollout/ep_len_mean": 446.2,
#     "rollout/ep_rew_mean": -33.0329475402832,
#     "time/fps": 420,
#     "time/iterations": 36,
#     "time/time_elapsed": 40,
#     "train/baseline": -0.11156665533781052,
#     "train/entropy": 2.077263593673706,
#     "train/entropy_loss": -0.002077263779938221,
#     "train/grad_norm": 0.285322368144989,
#     "train/loss": 0.5038319230079651,
#     "train/n_updates": 35,
#     "train/policy_gradient_loss": 0.4272960126399994,
#     "train/value_loss": 0.07861314713954926
# }
# {
#     "global_step": 18073,
#     "num_episodes": 39,
#     "rollout/ep_len_mean": 436.6,
#     "rollout/ep_rew_mean": -34.47076416015625,
#     "time/fps": 415,
#     "time/iterations": 39,
#     "time/time_elapsed": 43,
#     "train/baseline": -0.12113844603300095,
#     "train/entropy": 2.076894998550415,
#     "train/entropy_loss": -0.002076895209029317,
#     "train/grad_norm": 0.4051115810871124,
#     "train/loss": -0.4885518550872803,
#     "train/n_updates": 38,
#     "train/policy_gradient_loss": -0.5523607730865479,
#     "train/value_loss": 0.06588584184646606
# }
# {
#     "global_step": 19078,
#     "num_episodes": 42,
#     "rollout/ep_len_mean": 430.0,
#     "rollout/ep_rew_mean": -23.918088912963867,
#     "time/fps": 410,
#     "time/iterations": 42,
#     "time/time_elapsed": 46,
#     "train/baseline": -0.16772206127643585,
#     "train/entropy": 2.074613571166992,
#     "train/entropy_loss": -0.0020746137015521526,
#     "train/grad_norm": 0.07040880620479584,
#     "train/loss": -0.06423631310462952,
#     "train/n_updates": 41,
#     "train/policy_gradient_loss": -0.09384529292583466,
#     "train/value_loss": 0.03168359398841858
# }
# {
#     "global_step": 20183,
#     "num_episodes": 44,
#     "rollout/ep_len_mean": 438.2,
#     "rollout/ep_rew_mean": -47.35063934326172,
#     "time/fps": 412,
#     "time/iterations": 44,
#     "time/time_elapsed": 48,
#     "train/baseline": -0.15310269594192505,
#     "train/entropy": 2.075477361679077,
#     "train/entropy_loss": -0.0020754775032401085,
#     "train/grad_norm": 0.02981608919799328,
#     "train/loss": 0.06994260847568512,
#     "train/n_updates": 43,
#     "train/policy_gradient_loss": 0.040856726467609406,
#     "train/value_loss": 0.0311613567173481
# }
# {
#     "global_step": 21090,
#     "num_episodes": 45,
#     "rollout/ep_len_mean": 426.2,
#     "rollout/ep_rew_mean": -35.154014587402344,
#     "time/fps": 414,
#     "time/iterations": 45,
#     "time/time_elapsed": 50,
#     "train/baseline": -0.149662584066391,
#     "train/entropy": 2.075486421585083,
#     "train/entropy_loss": -0.002075486583635211,
#     "train/grad_norm": 0.1427815854549408,
#     "train/loss": -0.14104416966438293,
#     "train/n_updates": 44,
#     "train/policy_gradient_loss": -0.16966116428375244,
#     "train/value_loss": 0.030692487955093384
# }
# {
#     "global_step": 22088,
#     "num_episodes": 48,
#     "rollout/ep_len_mean": 432.6,
#     "rollout/ep_rew_mean": -30.451635360717773,
#     "time/fps": 416,
#     "time/iterations": 48,
#     "time/time_elapsed": 53,
#     "train/baseline": -0.12585973739624023,
#     "train/entropy": 2.0757250785827637,
#     "train/entropy_loss": -0.002075725235044956,
#     "train/grad_norm": 0.2849840521812439,
#     "train/loss": -0.31127098202705383,
#     "train/n_updates": 47,
#     "train/policy_gradient_loss": -0.3666904866695404,
#     "train/value_loss": 0.057495225220918655
# }
# {
#     "global_step": 23965,
#     "num_episodes": 51,
#     "rollout/ep_len_mean": 538.9,
#     "rollout/ep_rew_mean": -5.496299743652344,
#     "time/fps": 406,
#     "time/iterations": 51,
#     "time/time_elapsed": 59,
#     "train/baseline": -0.18000850081443787,
#     "train/entropy": 2.0727035999298096,
#     "train/entropy_loss": -0.00207270379178226,
#     "train/grad_norm": 0.1768989861011505,
#     "train/loss": 0.25693780183792114,
#     "train/n_updates": 50,
#     "train/policy_gradient_loss": 0.21075017750263214,
#     "train/value_loss": 0.04826033115386963
# }
# {
#     "global_step": 24212,
#     "num_episodes": 52,
#     "rollout/ep_len_mean": 513.4,
#     "rollout/ep_rew_mean": -10.891401290893555,
#     "time/fps": 406,
#     "time/iterations": 52,
#     "time/time_elapsed": 59,
#     "train/baseline": -0.15862153470516205,
#     "train/entropy": 2.073308229446411,
#     "train/entropy_loss": -0.0020733082201331854,
#     "train/grad_norm": 0.5573743581771851,
#     "train/loss": 0.7933554649353027,
#     "train/n_updates": 51,
#     "train/policy_gradient_loss": 0.6869816184043884,
#     "train/value_loss": 0.10844715684652328
# }
# {
#     "global_step": 25019,
#     "num_episodes": 54,
#     "rollout/ep_len_mean": 483.6,
#     "rollout/ep_rew_mean": 4.270425319671631,
#     "time/fps": 407,
#     "time/iterations": 54,
#     "time/time_elapsed": 61,
#     "train/baseline": -0.14662306010723114,
#     "train/entropy": 2.073497772216797,
#     "train/entropy_loss": -0.0020734979771077633,
#     "train/grad_norm": 0.3894260823726654,
#     "train/loss": -0.43948376178741455,
#     "train/n_updates": 53,
#     "train/policy_gradient_loss": -0.4867038428783417,
#     "train/value_loss": 0.04929356276988983
# }
# {
#     "global_step": 26479,
#     "num_episodes": 58,
#     "rollout/ep_len_mean": 439.1,
#     "rollout/ep_rew_mean": -17.573232650756836,
#     "time/fps": 409,
#     "time/iterations": 58,
#     "time/time_elapsed": 64,
#     "train/baseline": -0.17145410180091858,
#     "train/entropy": 2.069906234741211,
#     "train/entropy_loss": -0.0020699063315987587,
#     "train/grad_norm": 0.14159968495368958,
#     "train/loss": -0.05094414949417114,
#     "train/n_updates": 57,
#     "train/policy_gradient_loss": -0.12135180830955505,
#     "train/value_loss": 0.0724775642156601
# }
# {
#     "global_step": 27136,
#     "num_episodes": 60,
#     "rollout/ep_len_mean": 434.7,
#     "rollout/ep_rew_mean": -9.13728141784668,
#     "time/fps": 409,
#     "time/iterations": 60,
#     "time/time_elapsed": 66,
#     "train/baseline": -0.18308140337467194,
#     "train/entropy": 2.0675885677337646,
#     "train/entropy_loss": -0.002067588735371828,
#     "train/grad_norm": 0.20875096321105957,
#     "train/loss": -0.15551899373531342,
#     "train/n_updates": 59,
#     "train/policy_gradient_loss": -0.2047807276248932,
#     "train/value_loss": 0.05132932960987091
# }
# {
#     "global_step": 28162,
#     "num_episodes": 63,
#     "rollout/ep_len_mean": 373.3,
#     "rollout/ep_rew_mean": -16.618831634521484,
#     "time/fps": 411,
#     "time/iterations": 63,
#     "time/time_elapsed": 68,
#     "train/baseline": -0.11421409249305725,
#     "train/entropy": 2.0710930824279785,
#     "train/entropy_loss": -0.0020710930693894625,
#     "train/grad_norm": 0.0823858305811882,
#     "train/loss": -0.07934767752885818,
#     "train/n_updates": 62,
#     "train/policy_gradient_loss": -0.11648958921432495,
#     "train/value_loss": 0.03921300172805786
# }
# {
#     "global_step": 29145,
#     "num_episodes": 66,
#     "rollout/ep_len_mean": 344.8,
#     "rollout/ep_rew_mean": -20.76952362060547,
#     "time/fps": 408,
#     "time/iterations": 66,
#     "time/time_elapsed": 71,
#     "train/baseline": -0.13896562159061432,
#     "train/entropy": 2.0692129135131836,
#     "train/entropy_loss": -0.0020692129619419575,
#     "train/grad_norm": 0.1599521040916443,
#     "train/loss": 0.25595271587371826,
#     "train/n_updates": 65,
#     "train/policy_gradient_loss": 0.20115864276885986,
#     "train/value_loss": 0.05686328187584877
# }
# {
#     "global_step": 30240,
#     "num_episodes": 70,
#     "rollout/ep_len_mean": 310.4,
#     "rollout/ep_rew_mean": -15.707565307617188,
#     "time/fps": 409,
#     "time/iterations": 70,
#     "time/time_elapsed": 73,
#     "train/baseline": -0.16643156111240387,
#     "train/entropy": 2.0670461654663086,
#     "train/entropy_loss": -0.0020670462399721146,
#     "train/grad_norm": 0.1489044725894928,
#     "train/loss": -0.12495148181915283,
#     "train/n_updates": 69,
#     "train/policy_gradient_loss": -0.1757439374923706,
#     "train/value_loss": 0.05285950377583504
# }
# {
#     "global_step": 31151,
#     "num_episodes": 73,
#     "rollout/ep_len_mean": 298.9,
#     "rollout/ep_rew_mean": -42.0196533203125,
#     "time/fps": 410,
#     "time/iterations": 73,
#     "time/time_elapsed": 75,
#     "train/baseline": -0.1597106158733368,
#     "train/entropy": 2.0663511753082275,
#     "train/entropy_loss": -0.0020663512405008078,
#     "train/grad_norm": 0.24568095803260803,
#     "train/loss": -0.18980906903743744,
#     "train/n_updates": 72,
#     "train/policy_gradient_loss": -0.24289928376674652,
#     "train/value_loss": 0.055156558752059937
# }
# {
#     "global_step": 32738,
#     "num_episodes": 77,
#     "rollout/ep_len_mean": 338.5,
#     "rollout/ep_rew_mean": 0.5400558710098267,
#     "time/fps": 412,
#     "time/iterations": 77,
#     "time/time_elapsed": 79,
#     "train/baseline": -0.25053879618644714,
#     "train/entropy": 2.0459935665130615,
#     "train/entropy_loss": -0.0020459936931729317,
#     "train/grad_norm": 1.1101062297821045,
#     "train/loss": 1.1840647459030151,
#     "train/n_updates": 76,
#     "train/policy_gradient_loss": 0.9687575697898865,
#     "train/value_loss": 0.21735318005084991
# }
# {
#     "global_step": 33295,
#     "num_episodes": 78,
#     "rollout/ep_len_mean": 370.4,
#     "rollout/ep_rew_mean": 30.612573623657227,
#     "time/fps": 412,
#     "time/iterations": 78,
#     "time/time_elapsed": 80,
#     "train/baseline": -0.19150714576244354,
#     "train/entropy": 2.055743455886841,
#     "train/entropy_loss": -0.0020557434763759375,
#     "train/grad_norm": 0.8017714619636536,
#     "train/loss": 1.0040149688720703,
#     "train/n_updates": 77,
#     "train/policy_gradient_loss": 0.8253573775291443,
#     "train/value_loss": 0.18071334064006805
# }
# {
#     "global_step": 34170,
#     "num_episodes": 81,
#     "rollout/ep_len_mean": 362.9,
#     "rollout/ep_rew_mean": 25.593154907226562,
#     "time/fps": 411,
#     "time/iterations": 81,
#     "time/time_elapsed": 83,
#     "train/baseline": -0.1431531012058258,
#     "train/entropy": 2.0601367950439453,
#     "train/entropy_loss": -0.002060136990621686,
#     "train/grad_norm": 0.21382421255111694,
#     "train/loss": 0.4442756772041321,
#     "train/n_updates": 80,
#     "train/policy_gradient_loss": 0.28964555263519287,
#     "train/value_loss": 0.15669026970863342
# }
# {
#     "global_step": 35035,
#     "num_episodes": 83,
#     "rollout/ep_len_mean": 388.4,
#     "rollout/ep_rew_mean": 66.80863952636719,
#     "time/fps": 407,
#     "time/iterations": 83,
#     "time/time_elapsed": 85,
#     "train/baseline": -0.11171548813581467,
#     "train/entropy": 2.0613901615142822,
#     "train/entropy_loss": -0.0020613903179764748,
#     "train/grad_norm": 0.7224149703979492,
#     "train/loss": 1.1340724229812622,
#     "train/n_updates": 82,
#     "train/policy_gradient_loss": 0.9412262439727783,
#     "train/value_loss": 0.1949075609445572
# }
# {
#     "global_step": 36087,
#     "num_episodes": 86,
#     "rollout/ep_len_mean": 413.6,
#     "rollout/ep_rew_mean": 54.85622024536133,
#     "time/fps": 407,
#     "time/iterations": 86,
#     "time/time_elapsed": 88,
#     "train/baseline": -0.11082606762647629,
#     "train/entropy": 2.058941125869751,
#     "train/entropy_loss": -0.0020589411724358797,
#     "train/grad_norm": 0.2653331160545349,
#     "train/loss": 0.41856056451797485,
#     "train/n_updates": 85,
#     "train/policy_gradient_loss": 0.3461485803127289,
#     "train/value_loss": 0.07447094470262527
# }
# {
#     "global_step": 37271,
#     "num_episodes": 91,
#     "rollout/ep_len_mean": 310.1,
#     "rollout/ep_rew_mean": 10.243547439575195,
#     "time/fps": 408,
#     "time/iterations": 91,
#     "time/time_elapsed": 91,
#     "train/baseline": -0.14505358040332794,
#     "train/entropy": 2.051023483276367,
#     "train/entropy_loss": -0.002051023533567786,
#     "train/grad_norm": 0.06717267632484436,
#     "train/loss": 0.12530109286308289,
#     "train/n_updates": 90,
#     "train/policy_gradient_loss": 0.05391491577029228,
#     "train/value_loss": 0.07343720644712448
# }
# {
#     "global_step": 38170,
#     "num_episodes": 94,
#     "rollout/ep_len_mean": 269.9,
#     "rollout/ep_rew_mean": 21.370342254638672,
#     "time/fps": 409,
#     "time/iterations": 94,
#     "time/time_elapsed": 93,
#     "train/baseline": -0.10132502019405365,
#     "train/entropy": 2.060678482055664,
#     "train/entropy_loss": -0.002060678554698825,
#     "train/grad_norm": 0.23274099826812744,
#     "train/loss": 0.45838627219200134,
#     "train/n_updates": 93,
#     "train/policy_gradient_loss": 0.337009459733963,
#     "train/value_loss": 0.12343750149011612
# }
# {
#     "global_step": 39119,
#     "num_episodes": 97,
#     "rollout/ep_len_mean": 281.5,
#     "rollout/ep_rew_mean": 13.806012153625488,
#     "time/fps": 409,
#     "time/iterations": 97,
#     "time/time_elapsed": 95,
#     "train/baseline": -0.08558874577283859,
#     "train/entropy": 2.0563981533050537,
#     "train/entropy_loss": -0.002056398196145892,
#     "train/grad_norm": 0.29070982336997986,
#     "train/loss": -0.3127662241458893,
#     "train/n_updates": 96,
#     "train/policy_gradient_loss": -0.36334893107414246,
#     "train/value_loss": 0.052639108151197433
# }
# {
#     "global_step": 40176,
#     "num_episodes": 101,
#     "rollout/ep_len_mean": 290.5,
#     "rollout/ep_rew_mean": 28.37908935546875,
#     "time/fps": 407,
#     "time/iterations": 101,
#     "time/time_elapsed": 98,
#     "train/baseline": -0.06363697350025177,
#     "train/entropy": 2.055466413497925,
#     "train/entropy_loss": -0.0020554664079099894,
#     "train/grad_norm": 0.41164836287498474,
#     "train/loss": -0.4682796597480774,
#     "train/n_updates": 100,
#     "train/policy_gradient_loss": -0.5419569611549377,
#     "train/value_loss": 0.0757327675819397
# }
# {
#     "global_step": 41213,
#     "num_episodes": 105,
#     "rollout/ep_len_mean": 273.0,
#     "rollout/ep_rew_mean": 35.69517517089844,
#     "time/fps": 408,
#     "time/iterations": 105,
#     "time/time_elapsed": 100,
#     "train/baseline": -0.06403139978647232,
#     "train/entropy": 2.0469703674316406,
#     "train/entropy_loss": -0.0020469704177230597,
#     "train/grad_norm": 0.11851920932531357,
#     "train/loss": 0.241860494017601,
#     "train/n_updates": 104,
#     "train/policy_gradient_loss": 0.13860060274600983,
#     "train/value_loss": 0.10530686378479004
# }
# {
#     "global_step": 42170,
#     "num_episodes": 109,
#     "rollout/ep_len_mean": 246.6,
#     "rollout/ep_rew_mean": 54.279502868652344,
#     "time/fps": 409,
#     "time/iterations": 109,
#     "time/time_elapsed": 103,
#     "train/baseline": -0.02050234004855156,
#     "train/entropy": 2.040952444076538,
#     "train/entropy_loss": -0.002040952444076538,
#     "train/grad_norm": 0.5702556371688843,
#     "train/loss": 0.9016044735908508,
#     "train/n_updates": 108,
#     "train/policy_gradient_loss": 0.7045068144798279,
#     "train/value_loss": 0.1991385817527771
# }
# {
#     "global_step": 43145,
#     "num_episodes": 113,
#     "rollout/ep_len_mean": 248.8,
#     "rollout/ep_rew_mean": 63.07087326049805,
#     "time/fps": 410,
#     "time/iterations": 113,
#     "time/time_elapsed": 105,
#     "train/baseline": -0.0040350062772631645,
#     "train/entropy": 2.0417449474334717,
#     "train/entropy_loss": -0.002041744999587536,
#     "train/grad_norm": 0.18943201005458832,
#     "train/loss": 0.2760739028453827,
#     "train/n_updates": 112,
#     "train/policy_gradient_loss": 0.19397471845149994,
#     "train/value_loss": 0.08414092659950256
# }
# {
#     "global_step": 44123,
#     "num_episodes": 117,
#     "rollout/ep_len_mean": 246.1,
#     "rollout/ep_rew_mean": 62.133209228515625,
#     "time/fps": 410,
#     "time/iterations": 117,
#     "time/time_elapsed": 107,
#     "train/baseline": -0.0038600738625973463,
#     "train/entropy": 2.0268735885620117,
#     "train/entropy_loss": -0.002026873640716076,
#     "train/grad_norm": 0.78001868724823,
#     "train/loss": 1.1401140689849854,
#     "train/n_updates": 116,
#     "train/policy_gradient_loss": 0.8790295124053955,
#     "train/value_loss": 0.2631113529205322
# }
# {
#     "global_step": 45052,
#     "num_episodes": 121,
#     "rollout/ep_len_mean": 244.4,
#     "rollout/ep_rew_mean": 69.61880493164062,
#     "time/fps": 409,
#     "time/iterations": 121,
#     "time/time_elapsed": 110,
#     "train/baseline": 0.006205673795193434,
#     "train/entropy": 2.0228443145751953,
#     "train/entropy_loss": -0.0020228445064276457,
#     "train/grad_norm": 0.22353476285934448,
#     "train/loss": -0.11392280459403992,
#     "train/n_updates": 120,
#     "train/policy_gradient_loss": -0.1965789794921875,
#     "train/value_loss": 0.0846790224313736
# }
# {
#     "global_step": 46239,
#     "num_episodes": 126,
#     "rollout/ep_len_mean": 232.9,
#     "rollout/ep_rew_mean": 194.67404174804688,
#     "time/fps": 409,
#     "time/iterations": 126,
#     "time/time_elapsed": 112,
#     "train/baseline": 0.11210275441408157,
#     "train/entropy": 1.82563054561615,
#     "train/entropy_loss": -0.0018256306648254395,
#     "train/grad_norm": 2.857896327972412,
#     "train/loss": 2.320599317550659,
#     "train/n_updates": 125,
#     "train/policy_gradient_loss": 1.5599479675292969,
#     "train/value_loss": 0.762476921081543
# }
# {
#     "global_step": 47089,
#     "num_episodes": 131,
#     "rollout/ep_len_mean": 203.7,
#     "rollout/ep_rew_mean": 1027.6640625,
#     "time/fps": 409,
#     "time/iterations": 131,
#     "time/time_elapsed": 114,
#     "train/baseline": 2.936253547668457,
#     "train/entropy": 0.003623967058956623,
#     "train/entropy_loss": -3.6239671317161992e-06,
#     "train/grad_norm": 174.26336669921875,
#     "train/loss": 18.94097328186035,
#     "train/n_updates": 130,
#     "train/policy_gradient_loss": 0.002112217014655471,
#     "train/value_loss": 18.93886375427246
# }
# {
#     "global_step": 48072,
#     "num_episodes": 137,
#     "rollout/ep_len_mean": 164.4,
#     "rollout/ep_rew_mean": 2009.343017578125,
#     "time/fps": 410,
#     "time/iterations": 137,
#     "time/time_elapsed": 117,
#     "train/baseline": 8.5945405960083,
#     "train/entropy": 5.576540615948034e-07,
#     "train/entropy_loss": -5.576540895724236e-10,
#     "train/grad_norm": 36.28500747680664,
#     "train/loss": 0.5517903566360474,
#     "train/n_updates": 136,
#     "train/policy_gradient_loss": -0.0,
#     "train/value_loss": 0.5517903566360474
# }
# Решено!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>num_episodes</td><td>▁▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇█</td></tr><tr><td>rollout/ep_len_mean</td><td>▄▄▆▅▆▇▆▆▅██▇▇▆▆▆▆▅▆▇▆▆▆▅▄▃▄▅▄▅▃▃▃▃▃▂▂▂▂▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂█</td></tr><tr><td>time/fps</td><td>▇█▁▃▅▆▃▄▅▆▅▄▅▅▅▃▄▄▅▃▃▃▃▄▃▃▄▄▄▃▃▃▃▃▃▃▃▃▃▃</td></tr><tr><td>time/iterations</td><td>▁▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇█</td></tr><tr><td>time/time_elapsed</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train/baseline</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█</td></tr><tr><td>train/entropy</td><td>██████████████████████████████████████▇▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂█</td></tr><tr><td>train/grad_norm</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂█</td></tr><tr><td>train/loss</td><td>▁▁▁▃▂▁▃▂▂▃▂▂▂▃▃▂▂▂▁▃▁▂▂▂▃▂▅▅▃▅▂▃▁▁▃▃▅▂█▄</td></tr><tr><td>train/n_updates</td><td>▁▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇█</td></tr><tr><td>train/policy_gradient_loss</td><td>▂▁▂▄▃▁▄▂▃▃▃▃▂▄▄▃▃▂▂▄▁▂▂▃▄▂▆▆▄▆▃▄▂▁▃▄▆▂█▃</td></tr><tr><td>train/value_loss</td><td>▂▁▁▁▁▂▂▂▁▂▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▃▃▂▃▁▂▁▂▂▂▃▂█▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>48072</td></tr><tr><td>num_episodes</td><td>137</td></tr><tr><td>rollout/ep_len_mean</td><td>164.4</td></tr><tr><td>rollout/ep_rew_mean</td><td>2009.34302</td></tr><tr><td>time/fps</td><td>410</td></tr><tr><td>time/iterations</td><td>137</td></tr><tr><td>time/time_elapsed</td><td>117</td></tr><tr><td>train/baseline</td><td>8.59454</td></tr><tr><td>train/entropy</td><td>0.0</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>36.28501</td></tr><tr><td>train/loss</td><td>0.55179</td></tr><tr><td>train/n_updates</td><td>136</td></tr><tr><td>train/policy_gradient_loss</td><td>0</td></tr><tr><td>train/value_loss</td><td>0.55179</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">reinforce_value-baseline</strong> at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/4zi9m9d1' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/4zi9m9d1</a><br> View project at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251022_164758-4zi9m9d1/logs</code>

# %% [markdown]
# # 3 REINFORCE с разбиением на мини-батчи
# В предыдущих реализациях по данным одной собранной траетории стратегия обновлялась только один раз. Попробуем разбить траекторию на мини-батчи и обучаться на одной траектории в течение нескольких эпох. С одной стороны это должно привести к ускорению обучения, поскольку модели будут обновляться чаще. С другой стороны такая схема обучения отходит от on-policy режима.

# %%
class BatchedReturnBuffer(AverageReturnBuffer):
    def __init__(self, gamma: float = 0.99, device: Union[torch.device, str] = "cpu"):
        super().__init__(gamma, device)
        self.generator_ready = None

    def reset(self) -> None:
        super().reset()
        self.generator_ready = False

    def get(self, batch_size: Optional[Union[int, float]] = None) -> Generator[BufferSamples, None, None]:
        buffer_size = self.size()
        indices = np.random.permutation(buffer_size)
        if not self.generator_ready:
            self.observations = np.asarray(self.observations)
            self.actions = np.asarray(self.actions)
            self.returns = np.asarray(self.returns, dtype=np.float32)
            self.generator_ready = True

        if batch_size is None or math.isinf(batch_size):
            batch_size = buffer_size

        start_idx = 0
        while start_idx < buffer_size:
            yield self._get_samples(indices[start_idx: start_idx + batch_size])
            start_idx += batch_size

# %% [markdown]
# (3 балла)

# %%
class BatchedAverageReturnReinforce(Reinforce):
    def __init__(self, env: gym.Env, learning_rate: float = 2.5e-4, gamma: float = 0.99, ent_coef: float = 0.001,
                 max_grad_norm: float = 0.5, stats_window_size: int = 10, policy_class: Type[ReinforcePolicy] = ReinforcePolicy,
                 policy_kwargs: Optional[Dict[str, Any]] = None, buffer_class: Type[BatchedReturnBuffer] = BatchedReturnBuffer,
                 buffer_kwargs: Optional[Dict[str, Any]] = None, seed: Optional[int] = None,
                 device: Union[torch.device, str] = "cuda", batch_size: Union[int, float] = 64, n_epochs: int = 1):
        super().__init__(env, learning_rate, gamma, ent_coef, max_grad_norm, stats_window_size, policy_class, policy_kwargs,
                         buffer_class, buffer_kwargs, seed, device)
        self.batch_size = batch_size
        self.n_epochs = n_epochs

    def train(self) -> None:
        self.policy.set_training_mode(True)
        baseline = self.buffer.get_average_return()

        total_policy_loss = 0
        total_entropy_loss = 0
        total_entropy = 0
        total_loss = 0
        total_grad_norm = 0
        num_batches = 0
        for epoch in range(self.n_epochs):
            batches = self.buffer.get(self.batch_size)
            for batch in batches:
                actions = batch.actions.long()
                policy_output = self.policy.evaluate_actions(batch.observations, actions)
                log_prob = policy_output['log_prob']
                entropy = policy_output['entropy']

                advantages = batch.returns - baseline
                policy_loss = -(advantages * log_prob).mean()

                entropy_mean = torch.mean(entropy)
                entropy_loss = -1 * self.ent_coef * entropy_mean
                loss = policy_loss + entropy_loss

                self.policy.optimizer.zero_grad()
                loss.backward()
                grad_norm = nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
                self.policy.optimizer.step()

                total_policy_loss += policy_loss.item()
                total_entropy_loss += entropy_loss.item()
                total_entropy += entropy_mean.item()
                total_loss += loss.item()
                total_grad_norm += grad_norm.item()
                num_batches += 1
                self._n_updates += 1

        if num_batches > 0:
            policy_loss_avg = total_policy_loss / num_batches
            entropy_loss_avg = total_entropy_loss / num_batches
            entropy_avg = total_entropy / num_batches
            loss_avg = total_loss / num_batches
            grad_norm_avg = total_grad_norm / num_batches
        else:
            policy_loss_avg = 0.0
            entropy_loss_avg = 0.0
            entropy_avg = 0.0
            loss_avg = 0.0
            grad_norm_avg = 0.0

        self.log_dict = dict([
            ("train/entropy_loss", entropy_loss_avg),
            ("train/entropy", entropy_avg),
            ("train/policy_gradient_loss", policy_loss_avg),
            ("train/loss", loss_avg),
            ("train/grad_norm", grad_norm_avg),
            ("train/n_updates", self._n_updates),
            ("train/baseline", baseline)
        ])

# %% [markdown]
# ### Одна эпоха обучения

# %%
run_algorithm(
    algorithm_class=BatchedAverageReturnReinforce,
    algorithm_kwargs=dict(seed=0, batch_size=64, n_epochs=1),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_batch-epoch-1'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                    save_checkpoint_path='/content/drive/My Drive/seminar_actor-critic/reinforce_batch-epoch-1')
)
# Out:
# Using cuda device
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▂▃▅▆▇█</td></tr><tr><td>num_episodes</td><td>▁▃▄▅▆▇█</td></tr><tr><td>rollout/ep_len_mean</td><td>▃▁▃▄▇▇█</td></tr><tr><td>rollout/ep_rew_mean</td><td>▂█▆▆▂▁▁</td></tr><tr><td>time/fps</td><td>▂▇█▅▃▁▁</td></tr><tr><td>time/iterations</td><td>▁▃▄▅▆▇█</td></tr><tr><td>time/time_elapsed</td><td>▁▂▃▄▆▇█</td></tr><tr><td>train/baseline</td><td>▁█▆▅▄▄▄</td></tr><tr><td>train/entropy</td><td>█▁▁▁▁▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁██████</td></tr><tr><td>train/grad_norm</td><td>█▁▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>█▁▁▁▁▁▁</td></tr><tr><td>train/n_updates</td><td>▁▂▃▅▆▇█</td></tr><tr><td>train/policy_gradient_loss</td><td>█▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>7062</td></tr><tr><td>num_episodes</td><td>19</td></tr><tr><td>rollout/ep_len_mean</td><td>395.1</td></tr><tr><td>rollout/ep_rew_mean</td><td>-115.99924</td></tr><tr><td>time/fps</td><td>358</td></tr><tr><td>time/iterations</td><td>19</td></tr><tr><td>time/time_elapsed</td><td>19</td></tr><tr><td>train/baseline</td><td>0.13064</td></tr><tr><td>train/entropy</td><td>0.0</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>0.0</td></tr><tr><td>train/loss</td><td>-0.0</td></tr><tr><td>train/n_updates</td><td>110</td></tr><tr><td>train/policy_gradient_loss</td><td>0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">reinforce_batch-epoch-1</strong> at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/riu5buzy' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/riu5buzy</a><br> View project at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251022_165435-riu5buzy/logs</code>
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/content/wandb/run-20251022_165537-xmwaxsqp</code>
# Syncing run <strong><a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/xmwaxsqp' target="_blank">reinforce_batch-epoch-1</a></strong> to <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a>
#  View run at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/xmwaxsqp' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/xmwaxsqp</a>
# {
#     "global_step": 1042,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 347.3333333333333,
#     "rollout/ep_rew_mean": -89.53228759765625,
#     "time/fps": 445,
#     "time/iterations": 3,
#     "time/time_elapsed": 2,
#     "train/baseline": -0.14411527739344196,
#     "train/entropy": 2.079031070073446,
#     "train/entropy_loss": -0.0020790311585490904,
#     "train/grad_norm": 0.027967386568586033,
#     "train/loss": 0.03224312545110782,
#     "train/n_updates": 10,
#     "train/policy_gradient_loss": 0.03432215688129266
# }
# {
#     "global_step": 2289,
#     "num_episodes": 7,
#     "rollout/ep_len_mean": 327.0,
#     "rollout/ep_rew_mean": 42.01192092895508,
#     "time/fps": 443,
#     "time/iterations": 7,
#     "time/time_elapsed": 5,
#     "train/baseline": 0.6167305141574971,
#     "train/entropy": 7.143003699638939e-07,
#     "train/entropy_loss": -7.143003966092465e-10,
#     "train/grad_norm": 2.1256055617868697e-06,
#     "train/loss": -7.143003966092465e-10,
#     "train/n_updates": 31,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 3111,
#     "num_episodes": 9,
#     "rollout/ep_len_mean": 345.6666666666667,
#     "rollout/ep_rew_mean": 6.898730754852295,
#     "time/fps": 437,
#     "time/iterations": 9,
#     "time/time_elapsed": 7,
#     "train/baseline": 0.4340047999354848,
#     "train/entropy": 7.344226803849909e-07,
#     "train/entropy_loss": -7.344227051905453e-10,
#     "train/grad_norm": 1.831738456660657e-06,
#     "train/loss": -7.344227051905453e-10,
#     "train/n_updates": 45,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 4191,
#     "num_episodes": 12,
#     "rollout/ep_len_mean": 357.2,
#     "rollout/ep_rew_mean": -12.666340827941895,
#     "time/fps": 396,
#     "time/iterations": 12,
#     "time/time_elapsed": 10,
#     "train/baseline": 0.2822498812915492,
#     "train/entropy": 7.074788281139869e-07,
#     "train/entropy_loss": -7.074788625309006e-10,
#     "train/grad_norm": 1.4402871405157687e-06,
#     "train/loss": -7.074788625309006e-10,
#     "train/n_updates": 63,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 5078,
#     "num_episodes": 14,
#     "rollout/ep_len_mean": 388.9,
#     "rollout/ep_rew_mean": -90.1847152709961,
#     "time/fps": 404,
#     "time/iterations": 14,
#     "time/time_elapsed": 12,
#     "train/baseline": 0.22287289988339112,
#     "train/entropy": 7.124572221073322e-07,
#     "train/entropy_loss": -7.12457259854915e-10,
#     "train/grad_norm": 1.3247689404731016e-06,
#     "train/loss": -7.12457259854915e-10,
#     "train/n_updates": 76,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 6190,
#     "num_episodes": 17,
#     "rollout/ep_len_mean": 390.1,
#     "rollout/ep_rew_mean": -115.99893951416016,
#     "time/fps": 401,
#     "time/iterations": 17,
#     "time/time_elapsed": 15,
#     "train/baseline": 0.16180036442342643,
#     "train/entropy": 7.088093778091004e-07,
#     "train/entropy_loss": -7.088094123987155e-10,
#     "train/grad_norm": 9.875279955748638e-07,
#     "train/loss": -7.088094123987155e-10,
#     "train/n_updates": 98,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 7062,
#     "num_episodes": 19,
#     "rollout/ep_len_mean": 395.1,
#     "rollout/ep_rew_mean": -115.9992446899414,
#     "time/fps": 405,
#     "time/iterations": 19,
#     "time/time_elapsed": 17,
#     "train/baseline": 0.13063714198713303,
#     "train/entropy": 7.129809489470063e-07,
#     "train/entropy_loss": -7.129809798112063e-10,
#     "train/grad_norm": 1.1187753254186343e-06,
#     "train/loss": -7.129809798112063e-10,
#     "train/n_updates": 110,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 8179,
#     "num_episodes": 22,
#     "rollout/ep_len_mean": 398.8,
#     "rollout/ep_rew_mean": -115.99708557128906,
#     "time/fps": 407,
#     "time/iterations": 22,
#     "time/time_elapsed": 20,
#     "train/baseline": 0.0997568724498901,
#     "train/entropy": 7.115410604845758e-07,
#     "train/entropy_loss": -7.115410958848299e-10,
#     "train/grad_norm": 9.536228243892506e-07,
#     "train/loss": -7.115410958848299e-10,
#     "train/n_updates": 133,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 9132,
#     "num_episodes": 24,
#     "rollout/ep_len_mean": 405.4,
#     "rollout/ep_rew_mean": -115.9970474243164,
#     "time/fps": 397,
#     "time/iterations": 24,
#     "time/time_elapsed": 22,
#     "train/baseline": 0.08151084920505078,
#     "train/entropy": 7.170752464194916e-07,
#     "train/entropy_loss": -7.170752880369946e-10,
#     "train/grad_norm": 9.120270273602468e-07,
#     "train/loss": -7.170752880369946e-10,
#     "train/n_updates": 145,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 10335,
#     "num_episodes": 27,
#     "rollout/ep_len_mean": 414.5,
#     "rollout/ep_rew_mean": -115.99674224853516,
#     "time/fps": 402,
#     "time/iterations": 27,
#     "time/time_elapsed": 25,
#     "train/baseline": 0.06239934394776193,
#     "train/entropy": 7.153722473655458e-07,
#     "train/entropy_loss": -7.15372279932088e-10,
#     "train/grad_norm": 9.421478258294277e-07,
#     "train/loss": -7.15372279932088e-10,
#     "train/n_updates": 168,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 11429,
#     "num_episodes": 30,
#     "rollout/ep_len_mean": 394.8,
#     "rollout/ep_rew_mean": -115.99855041503906,
#     "time/fps": 405,
#     "time/iterations": 30,
#     "time/time_elapsed": 28,
#     "train/baseline": 0.042698662670492625,
#     "train/entropy": 7.137115668835273e-07,
#     "train/entropy_loss": -7.13711599079995e-10,
#     "train/grad_norm": 8.649840689637737e-07,
#     "train/loss": -7.13711599079995e-10,
#     "train/n_updates": 184,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 12036,
#     "num_episodes": 32,
#     "rollout/ep_len_mean": 385.7,
#     "rollout/ep_rew_mean": -115.9984359741211,
#     "time/fps": 406,
#     "time/iterations": 32,
#     "time/time_elapsed": 29,
#     "train/baseline": 0.0299301608890068,
#     "train/entropy": 7.280140295051751e-07,
#     "train/entropy_loss": -7.280140518206579e-10,
#     "train/grad_norm": 1.2325213276653812e-06,
#     "train/loss": -7.280140518206579e-10,
#     "train/n_updates": 196,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 13133,
#     "num_episodes": 35,
#     "rollout/ep_len_mean": 350.2,
#     "rollout/ep_rew_mean": -115.99833679199219,
#     "time/fps": 404,
#     "time/iterations": 35,
#     "time/time_elapsed": 32,
#     "train/baseline": 0.015137572240729414,
#     "train/entropy": 7.170865387706727e-07,
#     "train/entropy_loss": -7.170865790051551e-10,
#     "train/grad_norm": 9.902510669235198e-07,
#     "train/loss": -7.170865790051551e-10,
#     "train/n_updates": 213,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 14202,
#     "num_episodes": 38,
#     "rollout/ep_len_mean": 365.7,
#     "rollout/ep_rew_mean": -115.99848937988281,
#     "time/fps": 397,
#     "time/iterations": 38,
#     "time/time_elapsed": 35,
#     "train/baseline": 0.006028370947148266,
#     "train/entropy": 7.052446773871322e-07,
#     "train/entropy_loss": -7.052447118357666e-10,
#     "train/grad_norm": 6.699219251718855e-07,
#     "train/loss": -7.052447118357666e-10,
#     "train/n_updates": 235,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 15254,
#     "num_episodes": 40,
#     "rollout/ep_len_mean": 382.5,
#     "rollout/ep_rew_mean": -115.9988021850586,
#     "time/fps": 400,
#     "time/iterations": 40,
#     "time/time_elapsed": 38,
#     "train/baseline": 0.000144874550649548,
#     "train/entropy": 7.041037469611588e-07,
#     "train/entropy_loss": -7.041037814520874e-10,
#     "train/grad_norm": 5.323766427207172e-07,
#     "train/loss": -7.041037814520874e-10,
#     "train/n_updates": 249,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 16049,
#     "num_episodes": 42,
#     "rollout/ep_len_mean": 401.3,
#     "rollout/ep_rew_mean": -115.99906158447266,
#     "time/fps": 401,
#     "time/iterations": 42,
#     "time/time_elapsed": 39,
#     "train/baseline": -0.004433280909683073,
#     "train/entropy": 7.08574617647173e-07,
#     "train/entropy_loss": -7.085746526562057e-10,
#     "train/grad_norm": 7.291442614132393e-07,
#     "train/loss": -7.085746526562057e-10,
#     "train/n_updates": 263,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 17100,
#     "num_episodes": 44,
#     "rollout/ep_len_mean": 448.2,
#     "rollout/ep_rew_mean": -115.99909973144531,
#     "time/fps": 396,
#     "time/iterations": 44,
#     "time/time_elapsed": 43,
#     "train/baseline": -0.007282418983812854,
#     "train/entropy": 7.072328881721742e-07,
#     "train/entropy_loss": -7.072329287861511e-10,
#     "train/grad_norm": 4.29466271353621e-07,
#     "train/loss": -7.072329287861511e-10,
#     "train/n_updates": 281,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 18290,
#     "num_episodes": 47,
#     "rollout/ep_len_mean": 437.4,
#     "rollout/ep_rew_mean": -115.99761962890625,
#     "time/fps": 397,
#     "time/iterations": 47,
#     "time/time_elapsed": 46,
#     "train/baseline": -0.012785473552568255,
#     "train/entropy": 7.023185636019965e-07,
#     "train/entropy_loss": -7.023186014235941e-10,
#     "train/grad_norm": 7.78759082701678e-07,
#     "train/loss": -7.023186014235941e-10,
#     "train/n_updates": 302,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 19156,
#     "num_episodes": 49,
#     "rollout/ep_len_mean": 440.0,
#     "rollout/ep_rew_mean": -115.99759674072266,
#     "time/fps": 387,
#     "time/iterations": 49,
#     "time/time_elapsed": 49,
#     "train/baseline": -0.015932554007982193,
#     "train/entropy": 7.142518987685824e-07,
#     "train/entropy_loss": -7.142519274440571e-10,
#     "train/grad_norm": 6.490719946279049e-07,
#     "train/loss": -7.142519274440571e-10,
#     "train/n_updates": 315,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 20100,
#     "num_episodes": 51,
#     "rollout/ep_len_mean": 447.5,
#     "rollout/ep_rew_mean": -115.9976577758789,
#     "time/fps": 389,
#     "time/iterations": 51,
#     "time/time_elapsed": 51,
#     "train/baseline": -0.018839171322559033,
#     "train/entropy": 6.956123499435307e-07,
#     "train/entropy_loss": -6.95612387136002e-10,
#     "train/grad_norm": 5.426705769195905e-07,
#     "train/loss": -6.95612387136002e-10,
#     "train/n_updates": 330,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 21216,
#     "num_episodes": 54,
#     "rollout/ep_len_mean": 411.6,
#     "rollout/ep_rew_mean": -115.99763488769531,
#     "time/fps": 391,
#     "time/iterations": 54,
#     "time/time_elapsed": 54,
#     "train/baseline": -0.02388632039045771,
#     "train/entropy": 7.268870149346185e-07,
#     "train/entropy_loss": -7.268870505505731e-10,
#     "train/grad_norm": 9.0071515614909e-07,
#     "train/loss": -7.268870505505731e-10,
#     "train/n_updates": 350,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 22152,
#     "num_episodes": 56,
#     "rollout/ep_len_mean": 418.3,
#     "rollout/ep_rew_mean": -115.99818420410156,
#     "time/fps": 393,
#     "time/iterations": 56,
#     "time/time_elapsed": 56,
#     "train/baseline": -0.025916558319456984,
#     "train/entropy": 7.016453196229122e-07,
#     "train/entropy_loss": -7.016453473784878e-10,
#     "train/grad_norm": 4.007938358085994e-07,
#     "train/loss": -7.016453473784878e-10,
#     "train/n_updates": 367,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 23203,
#     "num_episodes": 58,
#     "rollout/ep_len_mean": 449.1,
#     "rollout/ep_rew_mean": -115.99920654296875,
#     "time/fps": 394,
#     "time/iterations": 58,
#     "time/time_elapsed": 58,
#     "train/baseline": -0.028712789856381513,
#     "train/entropy": 7.065589531723365e-07,
#     "train/entropy_loss": -7.065589841598947e-10,
#     "train/grad_norm": 4.5618211351615577e-07,
#     "train/loss": -7.065589841598947e-10,
#     "train/n_updates": 382,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 24077,
#     "num_episodes": 60,
#     "rollout/ep_len_mean": 444.5,
#     "rollout/ep_rew_mean": -115.99842834472656,
#     "time/fps": 391,
#     "time/iterations": 60,
#     "time/time_elapsed": 61,
#     "train/baseline": -0.03040936087994092,
#     "train/entropy": 7.19106206285384e-07,
#     "train/entropy_loss": -7.19106246771517e-10,
#     "train/grad_norm": 7.306877591872762e-07,
#     "train/loss": -7.19106246771517e-10,
#     "train/n_updates": 396,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 25096,
#     "num_episodes": 62,
#     "rollout/ep_len_mean": 459.0,
#     "rollout/ep_rew_mean": -115.99790954589844,
#     "time/fps": 393,
#     "time/iterations": 62,
#     "time/time_elapsed": 63,
#     "train/baseline": -0.032077297475726824,
#     "train/entropy": 7.189573933727742e-07,
#     "train/entropy_loss": -7.189574244590189e-10,
#     "train/grad_norm": 5.177022046609636e-07,
#     "train/loss": -7.189574244590189e-10,
#     "train/n_updates": 414,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 26206,
#     "num_episodes": 65,
#     "rollout/ep_len_mean": 437.6,
#     "rollout/ep_rew_mean": -115.99827575683594,
#     "time/fps": 394,
#     "time/iterations": 65,
#     "time/time_elapsed": 66,
#     "train/baseline": -0.03474158811484955,
#     "train/entropy": 6.924244563119178e-07,
#     "train/entropy_loss": -6.924244828303878e-10,
#     "train/grad_norm": 5.94057744202863e-07,
#     "train/loss": -6.924244828303878e-10,
#     "train/n_updates": 435,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 27171,
#     "num_episodes": 68,
#     "rollout/ep_len_mean": 396.8,
#     "rollout/ep_rew_mean": -115.99800872802734,
#     "time/fps": 396,
#     "time/iterations": 68,
#     "time/time_elapsed": 68,
#     "train/baseline": -0.039481620419813554,
#     "train/entropy": 7.091056772878801e-07,
#     "train/entropy_loss": -7.091057047103888e-10,
#     "train/grad_norm": 1.1036906641948008e-06,
#     "train/loss": -7.091057047103888e-10,
#     "train/n_updates": 453,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 28236,
#     "num_episodes": 71,
#     "rollout/ep_len_mean": 364.1,
#     "rollout/ep_rew_mean": -115.9986801147461,
#     "time/fps": 397,
#     "time/iterations": 71,
#     "time/time_elapsed": 70,
#     "train/baseline": -0.04448962322260327,
#     "train/entropy": 7.18859098469693e-07,
#     "train/entropy_loss": -7.188591388818111e-10,
#     "train/grad_norm": 9.753340179941006e-07,
#     "train/loss": -7.188591388818111e-10,
#     "train/n_updates": 468,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 29077,
#     "num_episodes": 73,
#     "rollout/ep_len_mean": 360.8,
#     "rollout/ep_rew_mean": -115.99870300292969,
#     "time/fps": 395,
#     "time/iterations": 73,
#     "time/time_elapsed": 73,
#     "train/baseline": -0.046102830906020735,
#     "train/entropy": 7.133998691541718e-07,
#     "train/entropy_loss": -7.133999070497844e-10,
#     "train/grad_norm": 4.0803548510363424e-07,
#     "train/loss": -7.133999070497844e-10,
#     "train/n_updates": 484,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 30169,
#     "num_episodes": 75,
#     "rollout/ep_len_mean": 396.3,
#     "rollout/ep_rew_mean": -115.99885559082031,
#     "time/fps": 396,
#     "time/iterations": 75,
#     "time/time_elapsed": 76,
#     "train/baseline": -0.04728302020523222,
#     "train/entropy": 7.151325955116287e-07,
#     "train/entropy_loss": -7.151326259564112e-10,
#     "train/grad_norm": 4.2652263548209e-07,
#     "train/loss": -7.151326259564112e-10,
#     "train/n_updates": 498,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 31284,
#     "num_episodes": 78,
#     "rollout/ep_len_mean": 411.3,
#     "rollout/ep_rew_mean": -115.99908447265625,
#     "time/fps": 397,
#     "time/iterations": 78,
#     "time/time_elapsed": 78,
#     "train/baseline": -0.04854629625340152,
#     "train/entropy": 7.182474551622622e-07,
#     "train/entropy_loss": -7.182474932270517e-10,
#     "train/grad_norm": 5.835607786203971e-07,
#     "train/loss": -7.182474932270517e-10,
#     "train/n_updates": 519,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 32032,
#     "num_episodes": 80,
#     "rollout/ep_len_mean": 422.3,
#     "rollout/ep_rew_mean": -115.9992904663086,
#     "time/fps": 398,
#     "time/iterations": 80,
#     "time/time_elapsed": 80,
#     "train/baseline": -0.04986130064815673,
#     "train/entropy": 7.091771294653881e-07,
#     "train/entropy_loss": -7.091771614398112e-10,
#     "train/grad_norm": 6.434897935984433e-07,
#     "train/loss": -7.091771614398112e-10,
#     "train/n_updates": 532,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 33313,
#     "num_episodes": 83,
#     "rollout/ep_len_mean": 423.6,
#     "rollout/ep_rew_mean": -115.99937438964844,
#     "time/fps": 399,
#     "time/iterations": 83,
#     "time/time_elapsed": 83,
#     "train/baseline": -0.052374202463002936,
#     "train/entropy": 6.931961801607637e-07,
#     "train/entropy_loss": -6.931962133934396e-10,
#     "train/grad_norm": 6.54999202727898e-07,
#     "train/loss": -6.931962133934396e-10,
#     "train/n_updates": 553,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 34193,
#     "num_episodes": 85,
#     "rollout/ep_len_mean": 402.4,
#     "rollout/ep_rew_mean": -115.99932861328125,
#     "time/fps": 398,
#     "time/iterations": 85,
#     "time/time_elapsed": 85,
#     "train/baseline": -0.05311650797507118,
#     "train/entropy": 6.925312234784542e-07,
#     "train/entropy_loss": -6.925312545646989e-10,
#     "train/grad_norm": 4.508799307245681e-07,
#     "train/loss": -6.925312545646989e-10,
#     "train/n_updates": 569,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 35241,
#     "num_episodes": 88,
#     "rollout/ep_len_mean": 395.7,
#     "rollout/ep_rew_mean": -115.99925231933594,
#     "time/fps": 398,
#     "time/iterations": 88,
#     "time/time_elapsed": 88,
#     "train/baseline": -0.055083371293597486,
#     "train/entropy": 7.139822931397551e-07,
#     "train/entropy_loss": -7.139823269645499e-10,
#     "train/grad_norm": 7.189320948934134e-07,
#     "train/loss": -7.139823269645499e-10,
#     "train/n_updates": 589,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 36353,
#     "num_episodes": 90,
#     "rollout/ep_len_mean": 432.1,
#     "rollout/ep_rew_mean": -115.99974060058594,
#     "time/fps": 399,
#     "time/iterations": 90,
#     "time/time_elapsed": 91,
#     "train/baseline": -0.05622679404813149,
#     "train/entropy": 7.073167580529116e-07,
#     "train/entropy_loss": -7.07316779221164e-10,
#     "train/grad_norm": 6.043456721727125e-07,
#     "train/loss": -7.07316779221164e-10,
#     "train/n_updates": 601,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 37173,
#     "num_episodes": 92,
#     "rollout/ep_len_mean": 436.2,
#     "rollout/ep_rew_mean": -115.99815368652344,
#     "time/fps": 400,
#     "time/iterations": 92,
#     "time/time_elapsed": 92,
#     "train/baseline": -0.056586999007724,
#     "train/entropy": 7.015933728585619e-07,
#     "train/entropy_loss": -7.015934103523794e-10,
#     "train/grad_norm": 5.270643563497808e-07,
#     "train/loss": -7.015934103523794e-10,
#     "train/n_updates": 620,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 38332,
#     "num_episodes": 94,
#     "rollout/ep_len_mean": 452.9,
#     "rollout/ep_rew_mean": -115.99700927734375,
#     "time/fps": 401,
#     "time/iterations": 94,
#     "time/time_elapsed": 95,
#     "train/baseline": -0.057301684530942,
#     "train/entropy": 6.997089043478708e-07,
#     "train/entropy_loss": -6.997089327695802e-10,
#     "train/grad_norm": 4.2401765654176415e-07,
#     "train/loss": -6.997089327695802e-10,
#     "train/n_updates": 636,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 39322,
#     "num_episodes": 97,
#     "rollout/ep_len_mean": 440.9,
#     "rollout/ep_rew_mean": -115.99693298339844,
#     "time/fps": 400,
#     "time/iterations": 97,
#     "time/time_elapsed": 98,
#     "train/baseline": -0.05910656071544717,
#     "train/entropy": 7.115628477549762e-07,
#     "train/entropy_loss": -7.115628826899941e-10,
#     "train/grad_norm": 6.359301210068224e-07,
#     "train/loss": -7.115628826899941e-10,
#     "train/n_updates": 658,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 40222,
#     "num_episodes": 99,
#     "rollout/ep_len_mean": 460.8,
#     "rollout/ep_rew_mean": -115.99664306640625,
#     "time/fps": 399,
#     "time/iterations": 99,
#     "time/time_elapsed": 100,
#     "train/baseline": -0.05993008727528925,
#     "train/entropy": 7.021853402225783e-07,
#     "train/entropy_loss": -7.021853654087806e-10,
#     "train/grad_norm": 5.229342353426805e-07,
#     "train/loss": -7.021853654087806e-10,
#     "train/n_updates": 671,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 41235,
#     "num_episodes": 102,
#     "rollout/ep_len_mean": 406.2,
#     "rollout/ep_rew_mean": -115.9971923828125,
#     "time/fps": 400,
#     "time/iterations": 102,
#     "time/time_elapsed": 102,
#     "train/baseline": -0.061967166337067475,
#     "train/entropy": 7.079066151050029e-07,
#     "train/entropy_loss": -7.079066499660058e-10,
#     "train/grad_norm": 4.1176316756263986e-07,
#     "train/loss": -7.079066499660058e-10,
#     "train/n_updates": 691,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 42090,
#     "num_episodes": 104,
#     "rollout/ep_len_mean": 375.8,
#     "rollout/ep_rew_mean": -115.9950942993164,
#     "time/fps": 401,
#     "time/iterations": 104,
#     "time/time_elapsed": 104,
#     "train/baseline": -0.06357386239336156,
#     "train/entropy": 7.074743507473613e-07,
#     "train/entropy_loss": -7.074743790802529e-10,
#     "train/grad_norm": 7.422058956763066e-07,
#     "train/loss": -7.074743790802529e-10,
#     "train/n_updates": 701,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 43240,
#     "num_episodes": 107,
#     "rollout/ep_len_mean": 391.8,
#     "rollout/ep_rew_mean": -115.99478912353516,
#     "time/fps": 402,
#     "time/iterations": 107,
#     "time/time_elapsed": 107,
#     "train/baseline": -0.06450056659353957,
#     "train/entropy": 7.09209335322417e-07,
#     "train/entropy_loss": -7.092093737678543e-10,
#     "train/grad_norm": 5.295508052378344e-07,
#     "train/loss": -7.092093737678543e-10,
#     "train/n_updates": 724,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 44141,
#     "num_episodes": 109,
#     "rollout/ep_len_mean": 391.9,
#     "rollout/ep_rew_mean": -115.99505615234375,
#     "time/fps": 402,
#     "time/iterations": 109,
#     "time/time_elapsed": 109,
#     "train/baseline": -0.06482619732407634,
#     "train/entropy": 7.050216837001244e-07,
#     "train/entropy_loss": -7.050217215587296e-10,
#     "train/grad_norm": 4.2361263652423986e-07,
#     "train/loss": -7.050217215587296e-10,
#     "train/n_updates": 738,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 45366,
#     "num_episodes": 112,
#     "rollout/ep_len_mean": 413.1,
#     "rollout/ep_rew_mean": -115.9952163696289,
#     "time/fps": 401,
#     "time/iterations": 112,
#     "time/time_elapsed": 113,
#     "train/baseline": -0.0663225066598531,
#     "train/entropy": 7.070633437756947e-07,
#     "train/entropy_loss": -7.070633769836989e-10,
#     "train/grad_norm": 3.677004687890278e-07,
#     "train/loss": -7.070633769836989e-10,
#     "train/n_updates": 759,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 46005,
#     "num_episodes": 113,
#     "rollout/ep_len_mean": 447.9,
#     "rollout/ep_rew_mean": -115.99845123291016,
#     "time/fps": 401,
#     "time/iterations": 113,
#     "time/time_elapsed": 114,
#     "train/baseline": -0.06657397265730382,
#     "train/entropy": 7.269396340754091e-07,
#     "train/entropy_loss": -7.269396592616114e-10,
#     "train/grad_norm": 5.790302119683994e-07,
#     "train/loss": -7.269396592616114e-10,
#     "train/n_updates": 766,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 47291,
#     "num_episodes": 116,
#     "rollout/ep_len_mean": 438.9,
#     "rollout/ep_rew_mean": -115.9981918334961,
#     "time/fps": 402,
#     "time/iterations": 116,
#     "time/time_elapsed": 117,
#     "train/baseline": -0.06693059870273249,
#     "train/entropy": 7.042287819558624e-07,
#     "train/entropy_loss": -7.042288141523301e-10,
#     "train/grad_norm": 4.4637704021965874e-07,
#     "train/loss": -7.042288141523301e-10,
#     "train/n_updates": 790,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 48197,
#     "num_episodes": 118,
#     "rollout/ep_len_mean": 446.4,
#     "rollout/ep_rew_mean": -115.99788665771484,
#     "time/fps": 403,
#     "time/iterations": 118,
#     "time/time_elapsed": 119,
#     "train/baseline": -0.06737904444409684,
#     "train/entropy": 6.998905064392602e-07,
#     "train/entropy_loss": -6.998905344168804e-10,
#     "train/grad_norm": 5.776683593694543e-07,
#     "train/loss": -6.998905344168804e-10,
#     "train/n_updates": 803,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 49330,
#     "num_episodes": 121,
#     "rollout/ep_len_mean": 435.8,
#     "rollout/ep_rew_mean": -115.99798583984375,
#     "time/fps": 403,
#     "time/iterations": 121,
#     "time/time_elapsed": 122,
#     "train/baseline": -0.0683122470528159,
#     "train/entropy": 7.119054525143534e-07,
#     "train/entropy_loss": -7.119054975153934e-10,
#     "train/grad_norm": 5.861963453905142e-07,
#     "train/loss": -7.119054975153934e-10,
#     "train/n_updates": 824,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 50394,
#     "num_episodes": 124,
#     "rollout/ep_len_mean": 401.9,
#     "rollout/ep_rew_mean": -115.99662017822266,
#     "time/fps": 402,
#     "time/iterations": 124,
#     "time/time_elapsed": 125,
#     "train/baseline": -0.06986726406640537,
#     "train/entropy": 7.077173011436701e-07,
#     "train/entropy_loss": -7.077173291847316e-10,
#     "train/grad_norm": 5.006765775306121e-07,
#     "train/loss": -7.077173291847316e-10,
#     "train/n_updates": 842,
#     "train/policy_gradient_loss": 0.0
# }
# Задача не решена за 50000 шагов
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>num_episodes</td><td>▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>rollout/ep_len_mean</td><td>▂▁▂▃▄▅▅▆▅▄▃▄▅▇▇▇▅▆▇▇▇▅▃▃▅▆▆▅▆▇▇█▅▄▄▆▇▇▇▅</td></tr><tr><td>rollout/ep_rew_mean</td><td>▂█▆▆▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time/fps</td><td>██▇▂▃▃▃▂▃▃▃▂▃▃▂▁▁▁▂▂▂▂▂▂▂▂▂▂▂▃▃▂▃▃▃▃▃▃▃▃</td></tr><tr><td>time/iterations</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>time/time_elapsed</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train/baseline</td><td>▁█▆▅▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂</td></tr><tr><td>train/entropy</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁███████████████████████████████████████</td></tr><tr><td>train/grad_norm</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/n_updates</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>train/policy_gradient_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>50394</td></tr><tr><td>num_episodes</td><td>124</td></tr><tr><td>rollout/ep_len_mean</td><td>401.9</td></tr><tr><td>rollout/ep_rew_mean</td><td>-115.99662</td></tr><tr><td>time/fps</td><td>402</td></tr><tr><td>time/iterations</td><td>124</td></tr><tr><td>time/time_elapsed</td><td>125</td></tr><tr><td>train/baseline</td><td>-0.06987</td></tr><tr><td>train/entropy</td><td>0.0</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>0.0</td></tr><tr><td>train/loss</td><td>-0.0</td></tr><tr><td>train/n_updates</td><td>842</td></tr><tr><td>train/policy_gradient_loss</td><td>0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">reinforce_batch-epoch-1</strong> at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/xmwaxsqp' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/xmwaxsqp</a><br> View project at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251022_165537-xmwaxsqp/logs</code>

# %% [markdown]
# ### Две эпохи обучения

# %%
run_algorithm(
    algorithm_class=BatchedAverageReturnReinforce,
    algorithm_kwargs=dict(seed=0, batch_size=64, n_epochs=2),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_batch-epoch-2'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                    save_checkpoint_path='/content/drive/My Drive/seminar_actor-critic/reinforce_batch-epoch-2')
)
# Out:
# Using cuda device
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/content/wandb/run-20251022_165747-95ifkiyn</code>
# Syncing run <strong><a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/95ifkiyn' target="_blank">reinforce_batch-epoch-2</a></strong> to <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a>
#  View run at <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/95ifkiyn' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/95ifkiyn</a>
# {
#     "global_step": 1300,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 433.3333333333333,
#     "rollout/ep_rew_mean": -91.2186050415039,
#     "time/fps": 445,
#     "time/iterations": 3,
#     "time/time_elapsed": 2,
#     "train/baseline": -0.13944392863409133,
#     "train/entropy": 1.9599554240703583,
#     "train/entropy_loss": -0.001959955542891597,
#     "train/grad_norm": 0.10917702224105597,
#     "train/loss": 0.030866783034677308,
#     "train/n_updates": 20,
#     "train/policy_gradient_loss": 0.03282673874249061
# }
# {
#     "global_step": 2159,
#     "num_episodes": 5,
#     "rollout/ep_len_mean": 431.8,
#     "rollout/ep_rew_mean": -67.19212341308594,
#     "time/fps": 430,
#     "time/iterations": 5,
#     "time/time_elapsed": 5,
#     "train/baseline": -0.10836702183645103,
#     "train/entropy": 1.9445352024502225,
#     "train/entropy_loss": -0.0019445352825439638,
#     "train/grad_norm": 0.18246834352612495,
#     "train/loss": 0.26408517070942455,
#     "train/n_updates": 60,
#     "train/policy_gradient_loss": 0.2660297093292077
# }
# {
#     "global_step": 3081,
#     "num_episodes": 7,
#     "rollout/ep_len_mean": 440.14285714285717,
#     "rollout/ep_rew_mean": -78.9468002319336,
#     "time/fps": 397,
#     "time/iterations": 7,
#     "time/time_elapsed": 7,
#     "train/baseline": -0.10339733030154256,
#     "train/entropy": 2.0626890808343887,
#     "train/entropy_loss": -0.0020626891491701826,
#     "train/grad_norm": 0.05916404153686017,
#     "train/loss": -0.17615962028503418,
#     "train/n_updates": 86,
#     "train/policy_gradient_loss": -0.17409693216904998
# }
# {
#     "global_step": 4091,
#     "num_episodes": 10,
#     "rollout/ep_len_mean": 409.1,
#     "rollout/ep_rew_mean": -76.97399139404297,
#     "time/fps": 389,
#     "time/iterations": 10,
#     "time/time_elapsed": 10,
#     "train/baseline": -0.07645542261365809,
#     "train/entropy": 2.079019606113434,
#     "train/entropy_loss": -0.0020790197110424438,
#     "train/grad_norm": 0.03516321939726671,
#     "train/loss": -0.08371024555526674,
#     "train/n_updates": 126,
#     "train/policy_gradient_loss": -0.08163122514573236
# }
# {
#     "global_step": 5468,
#     "num_episodes": 13,
#     "rollout/ep_len_mean": 416.8,
#     "rollout/ep_rew_mean": -77.46479034423828,
#     "time/fps": 398,
#     "time/iterations": 13,
#     "time/time_elapsed": 13,
#     "train/baseline": -0.08262754423787849,
#     "train/entropy": 2.078899249434471,
#     "train/entropy_loss": -0.0020788993570022285,
#     "train/grad_norm": 0.04189047799445689,
#     "train/loss": -0.24822332058101892,
#     "train/n_updates": 160,
#     "train/policy_gradient_loss": -0.24614442232996225
# }
# {
#     "global_step": 6036,
#     "num_episodes": 14,
#     "rollout/ep_len_mean": 418.7,
#     "rollout/ep_rew_mean": -85.51475524902344,
#     "time/fps": 400,
#     "time/iterations": 14,
#     "time/time_elapsed": 15,
#     "train/baseline": -0.07539599926142139,
#     "train/entropy": 2.0789358258247375,
#     "train/entropy_loss": -0.00207893589977175,
#     "train/grad_norm": 0.02613983042538166,
#     "train/loss": -0.10965706314891577,
#     "train/n_updates": 180,
#     "train/policy_gradient_loss": -0.10757812587544321
# }
# {
#     "global_step": 7160,
#     "num_episodes": 17,
#     "rollout/ep_len_mean": 407.9,
#     "rollout/ep_rew_mean": -83.9229736328125,
#     "time/fps": 401,
#     "time/iterations": 17,
#     "time/time_elapsed": 17,
#     "train/baseline": -0.06204806916923451,
#     "train/entropy": 2.0789315551519394,
#     "train/entropy_loss": -0.0020789316622540355,
#     "train/grad_norm": 0.04267081443686038,
#     "train/loss": -0.3690772717818618,
#     "train/n_updates": 226,
#     "train/policy_gradient_loss": -0.36699833907186985
# }
# {
#     "global_step": 8153,
#     "num_episodes": 19,
#     "rollout/ep_len_mean": 431.3,
#     "rollout/ep_rew_mean": -11.899133682250977,
#     "time/fps": 392,
#     "time/iterations": 19,
#     "time/time_elapsed": 20,
#     "train/baseline": -0.05412730365891147,
#     "train/entropy": 2.077782852309091,
#     "train/entropy_loss": -0.002077782925750528,
#     "train/grad_norm": 0.06398477658097233,
#     "train/loss": -0.40476631479603903,
#     "train/n_updates": 250,
#     "train/policy_gradient_loss": -0.4026885266814913
# }
# {
#     "global_step": 9021,
#     "num_episodes": 22,
#     "rollout/ep_len_mean": 414.1,
#     "rollout/ep_rew_mean": 160.2215118408203,
#     "time/fps": 389,
#     "time/iterations": 22,
#     "time/time_elapsed": 23,
#     "train/baseline": 0.2379543227890007,
#     "train/entropy": 1.7850356201330821,
#     "train/entropy_loss": -0.0017850357107818127,
#     "train/grad_norm": 1.2734913875659306,
#     "train/loss": 1.9511907895406086,
#     "train/n_updates": 290,
#     "train/policy_gradient_loss": 1.9529758195082347
# }
# {
#     "global_step": 10026,
#     "num_episodes": 25,
#     "rollout/ep_len_mean": 362.9,
#     "rollout/ep_rew_mean": 392.59466552734375,
#     "time/fps": 393,
#     "time/iterations": 25,
#     "time/time_elapsed": 25,
#     "train/baseline": 0.4308509608210643,
#     "train/entropy": 1.7730982542037963,
#     "train/entropy_loss": -0.0017730983439832927,
#     "train/grad_norm": 1.2573964953422547,
#     "train/loss": 2.168111836910248,
#     "train/n_updates": 322,
#     "train/policy_gradient_loss": 2.169884943962097
# }
# {
#     "global_step": 11031,
#     "num_episodes": 29,
#     "rollout/ep_len_mean": 287.8,
#     "rollout/ep_rew_mean": 670.9666748046875,
#     "time/fps": 395,
#     "time/iterations": 29,
#     "time/time_elapsed": 27,
#     "train/baseline": 0.76698585427898,
#     "train/entropy": 1.3802302777767181,
#     "train/entropy_loss": -0.0013802303437842056,
#     "train/grad_norm": 1.8817156553268433,
#     "train/loss": 1.8239677995443344,
#     "train/n_updates": 358,
#     "train/policy_gradient_loss": 1.8253480345010757
# }
# {
#     "global_step": 12019,
#     "num_episodes": 33,
#     "rollout/ep_len_mean": 266.6,
#     "rollout/ep_rew_mean": 666.7085571289062,
#     "time/fps": 396,
#     "time/iterations": 33,
#     "time/time_elapsed": 30,
#     "train/baseline": 0.9784470799661266,
#     "train/entropy": 1.645480106274287,
#     "train/entropy_loss": -0.001645480185591926,
#     "train/grad_norm": 0.782539501786232,
#     "train/loss": 0.2763928659260273,
#     "train/n_updates": 398,
#     "train/policy_gradient_loss": 0.2780383452773094
# }
# {
#     "global_step": 13135,
#     "num_episodes": 40,
#     "rollout/ep_len_mean": 183.3,
#     "rollout/ep_rew_mean": 566.1692504882812,
#     "time/fps": 391,
#     "time/iterations": 40,
#     "time/time_elapsed": 33,
#     "train/baseline": 1.3035259370531689,
#     "train/entropy": 0.9217449327309927,
#     "train/entropy_loss": -0.0009217449696734548,
#     "train/grad_norm": 1.5155160129070282,
#     "train/loss": 0.633204405506452,
#     "train/n_updates": 438,
#     "train/policy_gradient_loss": 0.6341261466344198
# }
# {
#     "global_step": 14166,
#     "num_episodes": 46,
#     "rollout/ep_len_mean": 172.0,
#     "rollout/ep_rew_mean": 1209.175048828125,
#     "time/fps": 390,
#     "time/iterations": 46,
#     "time/time_elapsed": 36,
#     "train/baseline": 1.8077618831786715,
#     "train/entropy": 0.08772765348354976,
#     "train/entropy_loss": -8.772765734950856e-05,
#     "train/grad_norm": 0.7902520646651586,
#     "train/loss": 0.0539835513724635,
#     "train/n_updates": 478,
#     "train/policy_gradient_loss": 0.05407127924263477
# }
# {
#     "global_step": 15011,
#     "num_episodes": 51,
#     "rollout/ep_len_mean": 172.7,
#     "rollout/ep_rew_mean": 1900.141845703125,
#     "time/fps": 392,
#     "time/iterations": 51,
#     "time/time_elapsed": 38,
#     "train/baseline": 2.3765143159274955,
#     "train/entropy": 0.0008779573642338315,
#     "train/entropy_loss": -8.779574140286665e-07,
#     "train/grad_norm": 0.029165297125776608,
#     "train/loss": 0.0005206325537680337,
#     "train/n_updates": 508,
#     "train/policy_gradient_loss": 0.0005215105144695068
# }
# Решено!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▂▂▃▃▄▄▅▅▆▆▇██</td></tr><tr><td>num_episodes</td><td>▁▁▂▂▂▃▃▃▄▄▅▅▆▇█</td></tr><tr><td>rollout/ep_len_mean</td><td>███▇▇▇▇█▇▆▄▃▁▁▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▁▁▁▁▁▂▃▄▄▃▆█</td></tr><tr><td>time/fps</td><td>█▆▂▁▂▂▃▁▁▁▂▂▁▁▁</td></tr><tr><td>time/iterations</td><td>▁▁▂▂▂▃▃▃▄▄▅▅▆▇█</td></tr><tr><td>time/time_elapsed</td><td>▁▂▂▃▃▄▄▅▅▅▆▆▇██</td></tr><tr><td>train/baseline</td><td>▁▁▁▁▁▁▁▁▂▃▄▄▅▆█</td></tr><tr><td>train/entropy</td><td>████████▇▇▆▇▄▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▁▁▁▁▂▂▃▂▅██</td></tr><tr><td>train/grad_norm</td><td>▁▂▁▁▁▁▁▁▆▆█▄▇▄▁</td></tr><tr><td>train/loss</td><td>▂▃▂▂▁▂▁▁▇█▇▃▄▂▂</td></tr><tr><td>train/n_updates</td><td>▁▂▂▃▃▃▄▄▅▅▆▆▇██</td></tr><tr><td>train/policy_gradient_loss</td><td>▂▃▂▂▁▂▁▁▇█▇▃▄▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>15011</td></tr><tr><td>num_episodes</td><td>51</td></tr><tr><td>rollout/ep_len_mean</td><td>172.7</td></tr><tr><td>rollout/ep_rew_mean</td><td>1900.14185</td></tr><tr><td>time/fps</td><td>392</td></tr><tr><td>time/iterations</td><td>51</td></tr><tr><td>time/time_elapsed</td><td>38</td></tr><tr><td>train/baseline</td><td>2.37651</td></tr><tr><td>train/entropy</td><td>0.00088</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>0.02917</td></tr><tr><td>train/loss</td><td>0.00052</td></tr><tr><td>train/n_updates</td><td>508</td></tr><tr><td>train/policy_gradient_loss</td><td>0.00052</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">reinforce_batch-epoch-2</strong> at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic/runs/95ifkiyn' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic/runs/95ifkiyn</a><br> View project at: <a href='https://wandb.ai/ulaelfray/seminar_actor-critic' target="_blank">https://wandb.ai/ulaelfray/seminar_actor-critic</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251022_165747-95ifkiyn/logs</code>
